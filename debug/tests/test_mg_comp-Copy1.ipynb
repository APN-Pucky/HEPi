# %%
import hepi
import smpl
import numpy as np
import hepi.madgraph as mg
import matplotlib.pyplot as plt
import hepi.resummino as rs
import time
print (mg.get_path())
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
print (rs.get_path())
# Out:
# /opt/MG5_aMC_v2_7_0/
# ~/git/resummino_ug_to_UX_vNLO/

# %%
for p in [2000002,1000002]:
    li = [hepi.Input(hepi.Order.NLO_PLUS_NLL,13000,p,1000022,"scenarioB.in","cteq6l1","cteq66",1., 1.,"NLL EXP FIX",precision=0.1,max_iters=10)]
    li = hepi.scale_scan(li,5,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    #print([str(i.__dict__) for i in li])
    rs_dl = rs.run(li,False,True)
    #rs_dl["lo"] = rs_dl["lo"]*1.1
    #rs_dl["nlo"] = rs_dl["nlo"]*1.1
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    rs_dl["nlo-rnlo"]=rs_dl["nlo"]-rs_dl["rnlo"]
    rs_dl["nll_expand"]=-rs_dl["nlo_plus_nll"]
    hepi.scale_plot(rs_dl,["lo","nlo","nll_expand","rnlo","vnlo","p_plus_k","nlo-rnlo"],cont=False,error=True)
    smpl.plot.show()
    hepi.central_scale_plot(rs_dl,["lo","nlo","nll_expand","rnlo","vnlo","p_plus_k","nlo-rnlo"],cont=False,error=True)
    smpl.plot.show()
# Out:
# Running: 23 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/7a6ff6726e434a689ba6b3e6542bb0f20d8c9ce9495c086c51e221aa9e92abef.out                       </pre>
#   </div>
# </div>
# Running: 23 jobs
# RESTART (9.783+/-0.009)e-06 None None ./output/bcd9002ffe8094f2f44f917726afb7c5d7bf85428a3d55821ae0e47f3e144d45.out
# RESTART (8.351+/-0.008)e-06 None None ./output/9b1d9ca21ccaa89c95d9e60d7e4a009559f3f81b9f4dec1cb40d46aaefa60392.out
# RESTART (7.293+/-0.007)e-06 None None ./output/fb3d95d6713c4457c450ff660cf1e0cea38dec72fff0121ea2deddd790eab5eb.out
# RESTART (6.476+/-0.006)e-06 None None ./output/9c78b30db6743825477942d360d96ead551bae89793798052a77a118c221de43.out
# RESTART (5.826+/-0.005)e-06 None None ./output/97acd9b1a2c04edd7fd62333d9f97963da731a628c4f6c9a2f4bca38051d1d7a.out
# RESTART (7.618+/-0.007)e-06 None None ./output/655df30a5a9a1cfe8a40ac671315fa19661eb456849b8ba3e5e77db2e3f34d39.out
# RESTART (6.503+/-0.006)e-06 None None ./output/e58c4947caf50832eb36ed59db387e547ce2fe1e82e6af0bd44ca4e299cd4f46.out
# RESTART (5.679+/-0.005)e-06 None None ./output/0490cfb8320bc376921fa149394b3e320fc145f3fbdeaecfb9ea082d41dbabd7.out
# RESTART (4.536+/-0.004)e-06 None None ./output/41f51e3d2db95cd23675462f55e6bc1d4e1b2e1522b4d6f9b0462951ce325f71.out
# RESTART (6.111+/-0.006)e-06 None None ./output/f781bde8e431dece32e35dbf77776a10736b6e696afe43022713e69f18680d85.out
# RESTART (5.217+/-0.005)e-06 None None ./output/78c73100e3ec6858393bd9dd522ab3c562c45aa2eaa1d3e12d8848421923f8c7.out
out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/a85afab1b646bb43ba7bc350be3834bb080aa7b7f3ca32aa9562ef59cea81ead.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/24453b66e9a4bc612cd847406a5e14d995d3ae87a107eb43ed89d93a6e6f9bea.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/5af5254a00795e18506f0d071c833ffa6512dc371900e7fd2c0c7acf73763ef1.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/4523b1a89724da00856c61b19b11512498a179774ef52076ae51cc80bee98b45.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/b0ec30123552ee25218713f0853e1f7e94f3d3e9642636f87a1637276f673186.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/bd0447e23ca23e6165576426ef12fd7d8720d5e742e1012a714cea8a80e98c92.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/ed0337db6c12abf73f2136065fb7b4a0b397c0319068121101a7144f0b5b243b.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/cbec16bda5d492ca78caee717c89f758f10e40dcdcbf646a6abdeacf3b9dc2e6.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/1dc6baaaf8a3ac1797c096419919fb7a5dedd50f11da0bb0161e38358c0011cc.out Stage: DONE Status DONE:</pre>
#   </div>
# </div>

# %%
for p in [1000021,]:
    li = [hepi.Input(hepi.Order.NLO_PLUS_NLL,13000,p,1000022,"scenarioB.in","cteq6l1","cteq66",1., 1.,"NLL EXP")]
    li = hepi.scale_scan(li,5,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    #print([str(i.__dict__) for i in li])
    rs_dl = rs.run(li,False,True)
    #rs_dl["lo"] = rs_dl["lo"]*1.1
    #rs_dl["nlo"] = rs_dl["nlo"]*1.1
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    rs_dl["nlo-rnlo"]=rs_dl["nlo"]-rs_dl["rnlo"]
    rs_dl["nlo_plus_nll"]=-rs_dl["nlo_plus_nll"]
    hepi.scale_plot(rs_dl,["lo","nlo","nlo_plus_nll","rnlo","vnlo","p_plus_k","nlo-rnlo"],cont=False,error=True)
    smpl.plot.show()
    hepi.central_scale_plot(rs_dl,["lo","nlo","nlo_plus_nll","rnlo","vnlo","p_plus_k","nlo-rnlo"],cont=False,error=True)
    smpl.plot.show()
# Out:
# Running: 23 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/908cf007b62be9ef1795da678824065fc2d0c6fc636dbc15c16ce3d85bbd5afc.out                       </pre>
#   </div>
# </div>

# %%
for p in [2000002,1000002,1000021,]:
    li = [hepi.Input(hepi.Order.NLO_PLUS_NLL,13000,p,1000022,"scenarioB.in","cteq6l1","cteq66",1., 1.,"NLL EXP")]
    li = hepi.scale_scan(li,5,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    #print([str(i.__dict__) for i in li])
    rs_dl = rs.run(li,False,True)
    #rs_dl["lo"] = rs_dl["lo"]*1.1
    #rs_dl["nlo"] = rs_dl["nlo"]*1.1
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    #rs_dl["nlo"]=rs_dl["nlo"]-rs_dl["rnlo"]
    rs_dl["nlo_plus_nll"]=-rs_dl["nlo_plus_nll"]
    hepi.scale_plot(rs_dl,["lo","nlo","nlo_plus_nll","rnlo","vnlo","p_plus_k"],cont=False,error=True)
    smpl.plot.show()
    hepi.central_scale_plot(rs_dl,["lo","nlo","nlo_plus_nll","rnlo","vnlo","p_plus_k"],cont=False,error=True)
    smpl.plot.show()
# Out:
# Running: 23 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# Running: 23 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# --------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-7e64a4c0bd4a> in <module>
#       6     #mg_dl = mg.run(li,False)
#       7     #print([str(i.__dict__) for i in li])
# ----> 8     rs_dl = rs.run(li,False,False)
#       9     #rs_dl["lo"] = rs_dl["lo"]*1.1
#      10     #rs_dl["nlo"] = rs_dl["nlo"]*1.1
#
# ~/.local/lib/python3.7/site-packages/hepi/resummino/run.py in run(params, noskip, bar, no_parse, para)
#      42     print("Running: " + str(len(params))  +" jobs" )
#      43     rps = _queue(params, noskip)
# ---> 44     _run(rps, bar, no_parse,para)
#      45     if not no_parse:
#      46         outs = LD2DL(rps)["out_path"]
#
# ~/.local/lib/python3.7/site-packages/hepi/resummino/run.py in _run(rps, bar, no_parse, para)
#     190     if not no_parse:
#     191         # Collect statuses
# --> 192         output = [p.wait() for p in processes]
#     193         return output
#     194     return []
#
# ~/.local/lib/python3.7/site-packages/hepi/resummino/run.py in <listcomp>(.0)
#     190     if not no_parse:
#     191         # Collect statuses
# --> 192         output = [p.wait() for p in processes]
#     193         return output
#     194     return []
#
# /usr/lib/python3.7/subprocess.py in wait(self, timeout)
#    1017             endtime = _time() + timeout
#    1018         try:
# -> 1019             return self._wait(timeout=timeout)
#    1020         except KeyboardInterrupt:
#    1021             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1651                         if self.returncode is not None:
#    1652                             break  # Another thread waited.
# -> 1653                         (pid, sts) = self._try_wait(0)
#    1654                         # Check the pid and loop as waitpid has been known to
#    1655                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1609             """All callers to this function MUST hold self._waitpid_lock."""
#    1610             try:
# -> 1611                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1612             except ChildProcessError:
#    1613                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO,7000,p,1000022,"sps1a1000_mod.in","cteq6l1","cteq66",1., 1.,"RT_GQMSBAR_W4")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    #print([str(i.__dict__) for i in li])
    rs_dl = rs.run(li,False,False)
    #rs_dl["lo"] = rs_dl["lo"]*1.1
    #rs_dl["nlo"] = rs_dl["nlo"]*1.1
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.central_scale_plot(rs_dl,["lo","nlo"],cont=False,error=False)
    
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
# Out:
# Running: 23 jobs
# skipFAILED  0.04539+/-0.00005 None None ./output/2736a721f00cc499398a5e98f06416af624226a9fece628af7d0d9ff81405a47.out
# skipFAILED  0.03390+/-0.00004 None None ./output/906b8266e948f0a4342d91b77c73ea40fe983f05b375d95c1ff7de463aae2579.out
# skipFAILED  0.04437+/-0.00005 None None ./output/939e036f5ce0d0ba6f0bcd8b99c725bf963494d06c018247c15545b8787ded24.out
# FAILED  0.03677+/-0.00004 None None ./output/c9072f0cafb925332c5cf2a5eeda0d4ad88597e5d8b2f9198b1b2de94077cd26.out
# FAILED  0.031419+/-0.000033 None None ./output/8bbc763febcf5976081b779e67e656b081450bada25977817e82b407a0ade726.out
# FAILED  0.024395+/-0.000026 None None ./output/18e151b3bad6b51fed4cd6d4b708bd4dc7b6e41cef5592b3f502b279fca0c211.out
# skipFAILED  0.030496+/-0.000032 None None ./output/595d74b380afd563381549f9702067a78d49e7447e9e6b54eb05ec5e55ec0068.out
# skipFAILED  0.022771+/-0.000024 None None ./output/8b384989e0efabb8ccee551c2ce80749dca6fd3122cced2e69033914672e054e.out
# skipFAILED  0.031110+/-0.000033 None None ./output/3a252b62017ed9b0ea86022dcd72c57e4ea489c838bedb2c68caad752fb6d0be.out
# FAILED  0.022029+/-0.000023 None None ./output/d88077e7e3a92c551ae592c0b4f6a98ee3316a18f8a90ec4f643a18343e430a6.out
# FAILED  0.019251+/-0.000020 None None ./output/ffea0730252095f2d69c8f426b260fae9dc21a6563352efd26e10cd4534ae65f.out
# FAILED  0.017104+/-0.000018 None None ./output/356b938496b59f8a8b0c93ce2fd7b0da7c28ec9d2cf64c7e3bb7f3bd46f3bf60.out
# skipFAILED  0.022143+/-0.000024 None None ./output/145557a7bb1ecda9c0e00fa4690daefa546ffa2295923bebef98bac3cf4923f9.out
# skipFAILED  0.016534+/-0.000018 None None ./output/e5c212fd452d1b14273a1d6b931f7bdf45ff1e8bda25540bae5da587520f5244.out
# skip

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO_PLUS_NLL,7000,p,1000022,"sps1a1000_mod.in","cteq6l1","cteq66",1., 1.,"RT_GQMSBAR_W4")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl["lo"] = rs_dl["lo"]*1.1
    #rs_dl["nlo"] = rs_dl["nlo"]*1.1
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo","nlo_plus_nll"],cont=False)
    
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-15fc9fafebf3> in <module>
#      10     #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
#      11     hepi.scale_plot(rs_dl,["lo","nlo","nlo_plus_nll"],cont=False)
# ---> 12     hepi.total_tex_table(rs_dl,"mu_f","test.tex")
#      13     #hepi.scale_plot(mg_dl,["nlo"],cont=True)
#      14     smpl.plot.show()
#
# ~/.local/lib/python3.7/site-packages/hepi/plot.py in total_tex_table(dict_list, key, fname)
#      22 def total_tex_table(dict_list,key,fname):
#      23  dl = dict_list
# ---> 24  mask = dl["nlo_pdf_central"]!= np.array(None)
#      25  with open(fname) as f:
#      26      for i in len(dl["lo"][mask]):
#
# KeyError: 'nlo_pdf_central'

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO_PLUS_NLL,7000,p,1000022,"sps1a1000_mod.in","cteq6l1","cteq66",1., 1.,"RT_QMSBAR_W4_nonres")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl["lo"] = rs_dl["lo"]*1.1
    #rs_dl["nlo"] = rs_dl["nlo"]*1.1
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo","nlo_plus_nll"],cont=False)
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
# Out:
# Running: 14 jobs

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO_PLUS_NLL,7000,p,1000022,"sps1a1000_mod.in","cteq6l1","cteq66",1., 1.,"RT_QMSBAR_W4")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl["lo"] = rs_dl["lo"]*1.1
    #rs_dl["nlo"] = rs_dl["nlo"]*1.1
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo","nlo_plus_nll"],cont=False)
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO,7000,p,1000022,"sps1a1000_mod.in","cteq66","cteq66",1., 1.,"RT_QGMSBAR_W2")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO,7000,p,1000022,"sps1a1000_mod.in","cteq66","cteq66",1., 1.,"RT13MSBAR")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO,7000,p,1000022,"sps1a1000_mod.in","cteq66","cteq66",1., 1.,"RT8MSBAR")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO,7000,p,1000022,"sps1a1000_mod.in","cteq66","cteq66",1., 1.,"RT3")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO,7000,p,1000022,"sps1a1000_mod.in","cteq66","cteq66",1., 1.,"RT2")]
    li = hepi.scale_scan(li,4+3,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    #mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO,7000,p,1000022,"sps1a1000_mod.in","cteq66","cteq66",1., 1.,"R")]
    li = hepi.scale_scan(li,7+6,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
# Out:
# skipskiplo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/6a134a116063580fb11a059b1c7261a05c24e2ef4b68eb9fad7322efa1faa892.out
# skipskipskiplo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/c932913aa3374ec123321e83da9c6632c8140d4aaee8c4fa3634b1b72fbd3d2a.out
# skipskipskipskipskiplo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/7ca1e8413fe3b4ba8828142d9c67c75ba21c4c7bbba08b9c0ef60befc9a71ad6.out
# lo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/cbc02969ee19f09ad184813adfcddc1be54336baf657d015310e567b062f5328.out
# lo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/28fbb734e022b1526f20ef16b463584952a878f2a8decd5fc10933bbb2c0c8d1.out
# skipskipskipskipskipskipskipskipskiplo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/cd6f6a6d9032bf351fd4876020c128a0b67a63e8f87d984ed192f2085252b12e.out
# lo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/c4a5ded833fdff07a7d27e5d9c437dac0955c402f8be9a77ae0774b604401eac.out
# lo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/d61aa13d99a7f38ad368d143964ff8585b7c75cc1f6faa574ae04dc00f7c5b83.out
# skipskipskipskipskiplo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/d88ff8f1e2a8717ead67f25a3e0e774a165324c67b84fab4b877c2e39d7d8bec.out
# skipskipskiplo None or lo= None
# nlo None or lo= None
# nlo+nll None or lo= None
# FAILED  None None None ./output/b9cfcb0f8b43a0d63aa92e976c551b3eeba24df46015cc6cfb49ee8b2ca35744.out
# skipskip./output/9b64ffc3901bc34e1a6740b19ed4f53b309356230f12c2c328f3b747f65e1db2.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip

# %%
for p in [2000002]:
    li = [hepi.Input(hepi.Order.NLO,7000,p,1000022,"sps1a1000_mod.in","cteq66","cteq66",1., 1.,"R")]
    li = hepi.scale_scan(li,4,10.)
    #li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    #li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    #rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/9b64ffc3901bc34e1a6740b19ed4f53b309356230f12c2c328f3b747f65e1db2.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"ALL_DONE_w7")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    mg_dl = mg.run(li,False)
    rs_dl = rs.run(li,False,False)
    rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
    #hepi.scale_plot(rs_dl,["ratio_nlo"],cont=False)
    #plt.ylim([1-0.05,1+0.05])
    #smpl.plot.show()
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ALL_DONE_w7_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ALL_DONE_w7_code_MG.out
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-8cebc1ba6c3a> in <module>
#       5     li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
#       6     rs_dl = rs.run(li,False,False)
# ----> 7     mg_dl = mg.run(li,False)
#       8     rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
#       9     hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in run(params, noskip)
#      37 def run(params: List[Input], noskip=False):
#      38     rps = _queue(params, noskip)
# ---> 39     _run(rps)
#      40     outs = LD2DL(rps)["dic"]
#      41     results = _parse(outs)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in _run(rps)
#     121             'bin/mg5_aMC --mode="MadSTR" --file {in} >> {out} && cp {slha} {bdir}/Cards/param_card.dat && cp {run} {bdir}/Cards/run_card.dat && sed -i \'s/.*= req_acc_FO/ 1 = req_acc_FO/g\' {bdir}/Cards/run_card.dat && echo "automatic_html_opening = False" >> {bdir}/Cards/amcatnlo_configuration.txt && nice -n 5 {bdir}/bin/calculate_xsect -f'
#     122         pp = subprocess.Popen(com.format(**rps[0].dic), shell=True)
# --> 123         pp.wait()
#     124     # Run commands in parallel
#     125     processes = []
#
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1077             endtime = _time() + timeout
#    1078         try:
# -> 1079             return self._wait(timeout=timeout)
#    1080         except KeyboardInterrupt:
#    1081             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1802                         if self.returncode is not None:
#    1803                             break  # Another thread waited.
# -> 1804                         (pid, sts) = self._try_wait(0)
#    1805                         # Check the pid and loop as waitpid has been known to
#    1806                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1760             """All callers to this function MUST hold self._waitpid_lock."""
#    1761             try:
# -> 1762                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1763             except ChildProcessError:
#    1764                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"ALL_DONE")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,False,False)
    mg_dl = mg.run(li,False)
    rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
    hepi.scale_plot(rs_dl,["ratio_nlo"],cont=False)   
    plt.ylim([1-0.1,1+0.1])
    smpl.plot.show()
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ALL_DONE_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ALL_DONE_code_MG.out

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"NLO_COMP")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,False,False)
    mg_dl = mg.run(li,False)
    rs_dl['ratio_nlo'] = rs_dl["nlo"]/mg_dl["nlo"]
    hepi.scale_plot(rs_dl,["lo","nlo","rnlo","vnlo","p_plus_k"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
    smpl.plot.show()
    hepi.scale_plot(rs_dl,["ratio_nlo"],cont=False)
    smpl.plot.show()

    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"NLO_COMP_MASS")
    li = [i]
    li = hepi.mass_scan([i],p, np.linspace(1000,4000,16),diff_L_R=20)
    rs_dl = rs.run(li,False,False)
    mg_dl = mg.run(li,False)
    rs_dl['ratio_nlo'] = (rs_dl["nlo"]-mg_dl["nlo"])/rs_dl["nlo"]
    
    hepi.mass_plot(rs_dl,p,"lo",logy=True)
    hepi.mass_plot(rs_dl,p,"nlo",logy=True)
    hepi.mass_plot(mg_dl,p,"nlo",logy=True)
    smpl.plot.show()
    hepi.mass_plot(rs_dl,p,"ratio_nlo",logy=False,label="ratio_nlo",yaxis="ratio")
    plt.ylim([-0.1,0.1])
    smpl.plot.show()
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_NLO_COMP_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_2000002_1000.0_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_1.0_mu_r_1.0_id_NLO_COMP_MASS_mass_2000002_1000.0_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_NLO_COMP_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_1000002_1000.0_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_1.0_mu_r_1.0_id_NLO_COMP_MASS_mass_1000002_1000.0_code_MG.out

# %%
for p in [-1000006,-2000006]:
    i = hepi.Input(hepi.Order.LO,13000,p,1000024,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"LO_COMP")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,True)
    mg_dl = mg.run(li,True)
    hepi.scale_plot(rs_dl,["lo"])
    hepi.scale_plot(mg_dl,["lo"],cont=True)
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.LO_energy_13000_particle1_-1000006_particle2_1000024_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.LO_energy_13000_particle1_-1000006_particle2_1000024_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_MG.out
# /usr/lib/python3.8/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.LO_energy_13000_particle1_-2000006_particle2_1000024_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.LO_energy_13000_particle1_-2000006_particle2_1000024_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_MG.out

# %%
for p in [1000005,2000005]:
    i = hepi.Input(hepi.Order.LO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"LO_COMP")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,True)
    mg_dl = mg.run(li,True)
    hepi.scale_plot(rs_dl,["lo"])
    hepi.scale_plot(mg_dl,["lo"],cont=True)
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.LO_energy_13000_particle1_1000005_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.LO_energy_13000_particle1_1000005_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_MG.out
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.LO_energy_13000_particle1_2000005_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.LO_energy_13000_particle1_2000005_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_MG.out

# %%
for p in [2000002,1000002,1000021]:
    i = hepi.Input(hepi.Order.LO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"LO_COMP")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,False)
    mg_dl = mg.run(li,False)
    hepi.scale_plot(rs_dl,["lo"])
    hepi.scale_plot(mg_dl,["lo"],cont=True)
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.LO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.LO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_MG.out
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.LO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.LO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_MG.out
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.LO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.LO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_COMP_code_MG.out

# %%
for p in [2000002,1000002,1000021]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,id="NLO_COMP")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,False)
    mg_dl = mg.run(li,False)
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_NLO_COMP_code_RS.out</pre>
#   </div>
# </div>
# ./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_NLO_COMP_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_NLO_COMP_code_RS.out</pre>
#   </div>
# </div>
# ./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_NLO_COMP_code_MG.out
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_NLO_COMP_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.NLO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_NLO_COMP_code_MG.out

# %%
for p in [2000002,1000002,1000021]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.)
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,False)
    mg_dll = mg.run(li,False)
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id__code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id__code_MG.out
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id__code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id__code_MG.out

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.)
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    dll = mg.run(li,False)
    hepi.scale_plot(dll,["nlo"])
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id__code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id__code_MG.out

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.)
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    dll = rs.run(li,True)
    hepi.scale_plot(dll,["nlo"])
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id__code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id__code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,id="DIAGHALF")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    dll = rs.run(li,True)
    hepi.scale_plot(dll,["nlo"])
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_DIAGHALF_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_DIAGHALF_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,id="OFFDIAGHALF")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    dll = rs.run(li,True)
    hepi.scale_plot(dll,["nlo"])
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_OFFDIAGHALF_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_OFFDIAGHALF_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,id="DIAGHALF")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    dll = rs.run(li,True)
    hepi.scale_plot(dll,["nlo"])
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_DIAGHALF_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_DIAGHALF_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,id="0.5x0.5symUUB")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    dll = rs.run(li,True)
    hepi.scale_plot(dll,["nlo"])
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_0.5x0.5symUUB_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_0.5x0.5symUUB_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
