# %%
import hepi
import smpl
import numpy as np
import hepi.madgraph as mg
import matplotlib.pyplot as plt
import hepi.resummino as rs
import time
from smpl import plot
print (mg.get_path())
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
print (rs.get_path())
# Out:
# /opt/MG5_aMC_v2_7_0/
# ~/git/resummino_ug_to_UX_vNLO/

# %%
from sklearn.metrics import auc
for run_plot in [False,]:
    for diff_m,scenario in [(2000,"scenarioB_mod.in"),(4000,"scenarioA.in"),]:
        pdfs = [("MSHT20lo_as130","MSHT20nlo_as118"), #("CT18NLO","CT18NLO"),  ("NNPDF40_lo_as_01180","NNPDF40_nlo_as_01180")
        ]
        for lo_pdf,nlo_pdf in pdfs:
            for p in [1000002]:
                li = [hepi.Input(hepi.Order.NLO_PLUS_NLL, 13000, p, 1000022, scenario, lo_pdf, nlo_pdf, 1., 1.,precision=0.001,max_iters=25,id="full_fixed_scale_r5")]

                
                li = hepi.scan_invariant_mass(li, diff_m,14+1,low=0.0001)
                #li = hepi.seven_point_scan(li)

                dl = rs.run(li, False)

                if not run_plot:
                    #dl = hepi.scale_error(li,dl)
                    #plot.data([],[],init=True,data_color='k')
                    #mask = dl["LO_SCALE"]!=np.array(None)
                    
                    #hepi.plot(dl, "invariant_mass", "LO",           plot_data=True,fill=True,logy=False, label="LO",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #hepi.plot(dl, "invariant_mass", "NLO",         plot_data=True,fill=True,logy=False, label="NLO",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #hepi.plot(dl, "invariant_mass", "NLO_PLUS_NLL", plot_data=True,fill=True,logy=False, label="NLO+NLL",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #plt.show()
                    #plt.savefig(input.get_output_dir() + get_job_name() +  "_inv_mass_" + str(p) + "_" + str(nlo_pdf) + "_" +str(scenario) + ".pdf")

                    hepi.mass_and_ratio_plot(dl,li,"invariant_mass",combined=True,plot_data=False,fill=True,scenario=scenario[0:8]+ " " + scenario[8],yscale=10**6,unit="ab")
                    plt.show()
                    #plt.savefig(input.get_output_dir()+ get_job_name()+"_mass_and_ratio_" + nlo_pdf + "_" + str(p)+ "_" + str("inv") + "_" +str(scenario) + ".pdf",bbox_inches = 'tight', pad_inches = 0)
    #wait()
# Out:
# Running: 15 jobs
# RESTART (2.3306+/-0.0009)e-08 None None ./output/3d7ad9e225af206be835b8cd7e0488cf2bf514254c93d79c63b0db576abf335e.out
# RESTART (8.2797+/-0.0032)e-07 None None ./output/520afb1dc95817e7842f7c7ba57e5fa44652586f22b1e7ebd59ba453c1c001af.out
# RESTART (1.3316+/-0.0005)e-06 None None ./output/183f1cc0187d26a76f79a0a90369678c0fe637a32497866a5fa859f2ba414637.out
# RESTART (1.8615+/-0.0007)e-06 None None ./output/6f59ed518f326e734ba8306c62cbd40764bf9657b112d68ab65af6d43ac4f2d8.out
out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/c97989c1173a3fd0b44e83ce383d505913871d4bfc0788e67b82b5c742b8e643.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/ff8cc7e07d6e1570c58d74bbcf6b8c24af4b8365bed5e8855b9c91a5850bfc72.out Stage: DONE Status DONE:</pre>
#   </div>
# </div>
# computed AUC using sklearn.metrics.auc: 0.0025844531239389975
# computed AUC using sklearn.metrics.auc: 0.00370038214749466
# computed AUC using sklearn.metrics.auc: 0.0036908150481101414
# computed AUC using sklearn.metrics.auc: 1999.9999999999998
# computed AUC using sklearn.metrics.auc: 1999.9999999999998
# computed AUC using sklearn.metrics.auc: 1999.9999999999998
# computed AUC using sklearn.metrics.auc: 1916.528313808221
# Running: 15 jobs
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/868dd7d00ea9b2e1bd4dfedc76705899037cd868d2f8978092d9c02dfb300e1b.out                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/868dd7d00ea9b2e1bd4dfedc76705899037cd868d2f8978092d9c02dfb300e1b.out Stage: real light quark emission - dipole - (onshell) Status 34:   2.1243e-12      1.58e-15    3.85e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/5e559efe9e9ae51140ec686177014312b25f8a51ae415e4361402a16f3d0172d.out Stage: real light quark emission - dipole - (onshell) Status 35:   1.0728e-10      7.19e-14    3.54e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/8fdbe7e8978ed137eb5338fdd436b1c754f4e68453fdeb8f695426ec2804ee7e.out Stage: real light quark emission - dipole - (onshell) Status 34:   1.7415e-10      1.30e-13    3.69e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/54ab708e3e1560dfbf46a81b0ea11e46230f80ab5bb1a1557566b8056dfeac49.out Stage: real light quark emission - dipole - (onshell) Status 34:   2.4704e-10      1.84e-13    3.69e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/b55f66f69ecd5ec64757a931b322f34375e1f4b9f320506e8abdcb0b3b024f2d.out Stage: real light quark emission - dipole - (onshell) Status 34:   3.3302e-10      2.49e-13    3.47e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/929fb46988c6e6bd9368f73bb5795c185310d9753467b7822ca3980ca3709ba7.out Stage: real light quark emission - dipole - (onshell) Status 34:   4.3722e-10      3.28e-13    3.28e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/157da439c9bd69e8d125c3d0181f05393e3cd1a9f9d9bb60c2ccd0ae7ef779b3.out Stage: real light quark emission - dipole - (onshell) Status 34:   5.6329e-10      4.25e-13    3.37e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/e1c55555c9eb464ef22cdded311f34c7a8a82cec79fbd692bb4927f82d4931fe.out Stage: real light quark emission - dipole - (onshell) Status 34:   7.1074e-10      5.41e-13    3.11e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/64874cb11982d97da21900f78f42625f2c51ee8895a99589b0d10c1eed872854.out Stage: real light quark emission - dipole - (onshell) Status 34:   8.6599e-10      6.71e-13    2.95e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/aa67428448886398884c37f6bbe28f9d1e126cb2ad4c5bd45710f0df070f5617.out Stage: real light quark emission - dipole - (onshell) Status 34:   9.8723e-10      8.03e-13    3.40e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/8e8558b576feae6049eb4a4bad32d40cb72b271b88ef964dfc65501cc5f73be6.out Stage: real light quark emission - dipole - (onshell) Status 34:   9.9165e-10      9.20e-13    2.57e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/0e99551243ea83cc442ac5ddc7320ddef16624d8e7e8b04c473dd923f39cd144.out Stage: real light quark emission - dipole - (onshell) Status 34:   7.9054e-10      9.87e-13    2.33e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/440b2167ca784d2978a1a515e32a75b02fa7f5fac2dd7782c3d2388ab83667a3.out Stage: real light quark emission - dipole - (onshell) Status 64:   1.0360e-09      1.27e-11    8.66e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/041c0edf76f2998d6c0d3780ec4fffc8d6e33c5cd719f104291aca04aa14872a.out Stage: real light quark emission - dipole - (onshell) Status 77:   3.6173e-10      8.77e-13    9.25e-01</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/c1669f50eea116286fc15ee15069dfd5a664bca13fc0372c8403e5c12d938337.out Stage: real light quark emission - dipole - (onshell) Status 34:   7.3550e-12      1.89e-14    7.35e-01</pre>
#   </div>
# </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-334cdecee806> in <module>
#      12                 #li = hepi.seven_point_scan(li)
#      13
# ---> 14                 dl = rs.run(li, False)
#      15
#      16                 if not run_plot:
#
# ~/.local/lib/python3.7/site-packages/hepi/resummino/run.py in run(params, noskip, bar, no_parse, para)
#      44     print("Running: " + str(len(params))  +" jobs" )
#      45     rps = _queue(params, noskip)
# ---> 46     _run(rps, bar, no_parse,para)
#      47     if not no_parse:
#      48         outs = LD2DL(rps)["out_path"]
#
# ~/.local/lib/python3.7/site-packages/hepi/resummino/run.py in _run(rps, bar, no_parse, para)
#     160         while c:
#     161             if len(processes) > 0:
# --> 162                 time.sleep(10)
#     163             c = False
#     164             for p in processes:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import auc
for run_plot in [False,]:
    for diff_m,scenario in [(2000,"scenarioB_mod.in"),(4000,"scenarioA.in"),]:
        pdfs = [("MSHT20lo_as130","MSHT20nlo_as118"), #("CT18NLO","CT18NLO"),  ("NNPDF40_lo_as_01180","NNPDF40_nlo_as_01180")
        ]
        for lo_pdf,nlo_pdf in pdfs:
            for p in [1000021]:
                li = [hepi.Input(hepi.Order.NLO_PLUS_NLL, 13000, p, 1000022, scenario, lo_pdf, nlo_pdf, 1., 1.,precision=0.001,max_iters=25,id="full_fixed_scale_r3")]

                
                li = hepi.scan_invariant_mass(li, diff_m,14+1)
                #li = hepi.seven_point_scan(li)

                dl = rs.run(li, False)

                if not run_plot:
                    #dl = hepi.scale_error(li,dl)
                    #plot.data([],[],init=True,data_color='k')
                    #mask = dl["LO_SCALE"]!=np.array(None)
                    
                    #hepi.plot(dl, "invariant_mass", "LO",           plot_data=True,fill=True,logy=False, label="LO",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #hepi.plot(dl, "invariant_mass", "NLO",         plot_data=True,fill=True,logy=False, label="NLO",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #hepi.plot(dl, "invariant_mass", "NLO_PLUS_NLL", plot_data=True,fill=True,logy=False, label="NLO+NLL",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #plt.show()
                    #plt.savefig(input.get_output_dir() + get_job_name() +  "_inv_mass_" + str(p) + "_" + str(nlo_pdf) + "_" +str(scenario) + ".pdf")
                    print(dl["LO"])
                    print(dl["NLO"])
                    print(dl["NLO_PLUS_NLL"])
                    hepi.mass_and_ratio_plot(dl,li,"invariant_mass",combined=True,plot_data=False,fill=True,scenario=scenario[0:8]+ " " + scenario[8],yscale=10**6,unit="ab")
                    plt.show()
                    #plt.savefig(input.get_output_dir()+ get_job_name()+"_mass_and_ratio_" + nlo_pdf + "_" + str(p)+ "_" + str("inv") + "_" +str(scenario) + ".pdf",bbox_inches = 'tight', pad_inches = 0)
    #wait()
# Out:
# Running: 15 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/98ebc3830c42a8af3230f2376164081f0992516b1fb92c134bd0a86db1536f26.out                       </pre>
#   </div>
# </div>
# [4.212694e-15+/-3.5988337e-18 3.6620047e-11+/-1.641452e-14
#  1.5518722e-10+/-6.9636193e-14 4.3826109e-10+/-1.9672267e-13
#  1.0574545e-09+/-4.7472103e-13 2.3431136e-09+/-1.0519679e-12
#  4.8865755e-09+/-2.1939858e-12 9.6190126e-09+/-4.3186158e-12
#  1.7648892e-08+/-7.9222788e-12 2.9351264e-08+/-1.3170432e-11
#  4.2246275e-08+/-1.8955999e-11 4.9131586e-08+/-2.2071539e-11
#  4.1935469e-08+/-1.885524e-11 2.3025456e-08+/-1.0426289e-11
#  6.6569632e-09+/-3.042999e-12]
# [1.0695348e-11+/-9.0044136e-16 4.1720354e-10+/-2.2787845e-14
#  7.6601252e-10+/-8.7518579e-14 1.289077e-09+/-2.3741552e-13
#  2.167598e-09+/-5.2933747e-13 3.7214913e-09+/-1.07631e-12
#  6.4901241e-09+/-2.2295677e-12 1.1254316e-08+/-4.3516188e-12
#  1.8479114e-08+/-7.9523787e-12 2.7285835e-08+/-1.3104663e-11
#  3.6768716e-08+/-1.8603964e-11 3.9361701e-08+/-2.0993279e-11
#  2.9410129e-08+/-1.7230509e-11 1.2621985e-08+/-8.6495997e-12
#  2.2677909e-09+/-1.7352256e-12]
# [1.0695663e-11+/-9.0056236e-16 4.1988249e-10+/-2.7582968e-14
#  7.7735564e-10+/-1.0996125e-13 1.3210713e-09+/-3.036742e-13
#  2.2446403e-09+/-7.0046039e-13 3.8916464e-09+/-1.475946e-12
#  6.8428524e-09+/-2.9537523e-12 1.1941905e-08+/-5.6353311e-12
#  1.9719677e-08+/-9.8601823e-12 2.9302829e-08+/-1.7018797e-11
#  3.9551232e-08+/-2.4764515e-11 4.2333683e-08+/-2.2005263e-11
#  3.1614336e-08+/-2.1943802e-11 1.3521253e-08+/-1.2055001e-11
#  2.4199629e-09+/-2.7755144e-12]
# computed AUC using sklearn.metrics.auc: 5.31707960377452e-05
# computed AUC using sklearn.metrics.auc: 3.706596594513601e-05
# computed AUC using sklearn.metrics.auc: 3.9783313183901916e-05
# computed AUC using sklearn.metrics.auc: 2000.0
# computed AUC using sklearn.metrics.auc: 2000.0
# computed AUC using sklearn.metrics.auc: 2000.0
# computed AUC using sklearn.metrics.auc: 2141.786280518333
# Running: 15 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/7ad145fbb674d09a24fdd1372d38f1f54576757503100d19065f08a48ac7e4ec.out                       </pre>
#   </div>
# </div>
# [8.5554349e-17+/-7.5561436e-20 6.0506535e-13+/-2.409184e-16
#  2.5653669e-12+/-1.0214707e-15 7.2669551e-12+/-2.8938465e-15
#  1.7629582e-11+/-7.0218471e-15 3.9401964e-11+/-1.5699361e-14
#  8.323698e-11+/-3.3184536e-14 1.6678799e-10+/-6.6559155e-14
#  3.1265743e-10+/-1.2496768e-13 5.2975274e-10+/-2.1226523e-13
#  7.608254e-10+/-3.0543603e-13 8.2972656e-10+/-3.3391027e-13
#  5.692302e-10+/-2.3045835e-13 1.705964e-10+/-6.9515959e-14
#  8.7802219e-12+/-3.5442765e-15]
# [5.4603095e-13+/-1.5801703e-14 1.67964e-12+/-1.0720034e-14
#  1.9964873e-12+/-4.6872698e-15 4.5648018e-12+/-4.3346349e-15
#  1.0631318e-11+/-9.1659943e-15 2.3265486e-11+/-1.7641787e-14
#  4.8074556e-11+/-3.625839e-14 9.3610493e-11+/-7.0915716e-14
#  1.6826254e-10+/-1.3460392e-13 2.6638923e-10+/-2.129314e-13
#  3.4112806e-10+/-2.7192495e-13 3.0474746e-10+/-2.4187204e-13
#  1.4696441e-10+/-1.1563281e-13 2.3357489e-11+/-1.8284698e-14
#  4.209133e-13+/-3.2678952e-16]
# [5.4603852e-13+/-1.5801703e-14 1.7011382e-12+/-1.0720755e-14
#  2.086855e-12+/-4.717656e-15 4.8197052e-12+/-4.5908809e-15
#  1.1247089e-11+/-9.8638571e-15 2.4633491e-11+/-1.9398803e-14
#  5.0937727e-11+/-3.9906064e-14 9.9235992e-11+/-8.2815246e-14
#  1.7852059e-10+/-1.5896827e-13 2.8295932e-10+/-2.7469998e-13
#  3.6311721e-10+/-3.047375e-13 3.2528107e-10+/-2.9901887e-13
#  1.574892e-10+/-1.2097778e-13 2.5169445e-11+/-4.1228215e-14
#  4.5598804e-13+/-3.7476351e-16]
# computed AUC using sklearn.metrics.auc: 1.3309338128356373e-06
# computed AUC using sklearn.metrics.auc: 4.4954541815921747e-07
# computed AUC using sklearn.metrics.auc: 4.796408184224274e-07
# computed AUC using sklearn.metrics.auc: 4000.0
# computed AUC using sklearn.metrics.auc: 4000.0
# computed AUC using sklearn.metrics.auc: 4000.0
# computed AUC using sklearn.metrics.auc: 4294.745901833973

# %%
from sklearn.metrics import auc
for run_plot in [False,]:
    for diff_m,scenario in [(2000,"scenarioB_mod.in"),(4000,"scenarioA.in"),]:
        pdfs = [("MSHT20lo_as130","MSHT20nlo_as118"), #("CT18NLO","CT18NLO"),  ("NNPDF40_lo_as_01180","NNPDF40_nlo_as_01180")
        ]
        for lo_pdf,nlo_pdf in pdfs:
            for p in [1000002,1000021]:
                li = [hepi.Input(hepi.Order.NLO_PLUS_NLL, 13000, p, 1000022, scenario, lo_pdf, nlo_pdf, 1., 1.,precision=0.001,max_iters=25,id="exp_full_fixed_scale_r1")]

                
                li = hepi.scan_invariant_mass(li, diff_m,14+1,low=0.0001)
                #li = hepi.seven_point_scan(li)

                dl = rs.run(li, False)

                if not run_plot:
                    #dl = hepi.scale_error(li,dl)
                    #plot.data([],[],init=True,data_color='k')
                    #mask = dl["LO_SCALE"]!=np.array(None)
                    
                    #hepi.plot(dl, "invariant_mass", "LO",           plot_data=True,fill=True,logy=False, label="LO",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #hepi.plot(dl, "invariant_mass", "NLO",         plot_data=True,fill=True,logy=False, label="NLO",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #hepi.plot(dl, "invariant_mass", "NLO_PLUS_NLL", plot_data=True,fill=True,logy=False, label="NLO+NLL",xaxis="$M$ [GeV]",yaxis="$d\\sigma/dM$ [pb/GeV]")
                    #plt.show()
                    #plt.savefig(input.get_output_dir() + get_job_name() +  "_inv_mass_" + str(p) + "_" + str(nlo_pdf) + "_" +str(scenario) + ".pdf")
                    print(dl["LO"])
                    print(dl["NLO"])
                    print(dl["NLO_PLUS_NLL"])
                    hepi.mass_and_ratio_plot(dl,li,"invariant_mass",combined=True,plot_data=False,fill=True,scenario=scenario[0:8]+ " " + scenario[8],yscale=10**6,unit="ab")
                    plt.show()
                    #plt.savefig(input.get_output_dir()+ get_job_name()+"_mass_and_ratio_" + nlo_pdf + "_" + str(p)+ "_" + str("inv") + "_" +str(scenario) + ".pdf",bbox_inches = 'tight', pad_inches = 0)
    #wait()
# Out:
# Running: 15 jobs
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/c19e030eea2e0b7452baff370eea288e688baef35ceb42a9fbf80103952686d9.out                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/c19e030eea2e0b7452baff370eea288e688baef35ceb42a9fbf80103952686d9.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/1bb83dbcacb2522cbfd4e03922398a0fdfad29b26da95386d76fd33983220e2a.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/6278ee99fa3e5c8e96e16e20bc2d41773cea3df82de4752b4cac34f5b29dac36.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/c2bb91074c36492a3192db549c15e053d7745d80e32034adf9b8d763631cfd2a.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/2d142246b2fff38cd11b1e9b37fde3e3cc8f04ea91827e79fe673f5d61f167e6.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/442a840b6585ccce2d2ec94717784eb844f9722968831a7d2fdea0420907f88d.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/2a112fa8c1f35c9404a9fa3567c7a1ebd0fb614c1e897a235b6540e3869afbaf.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/662c819867cc089d7b96bee8a0acaf9c324f589a3248a06ee6b969c37936c401.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output/c5a14bbe766fe904ec0a27994e514924da2725239b817bc06d99c9a714a04fa4.out Stage: DONE Status DONE:</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... ./output