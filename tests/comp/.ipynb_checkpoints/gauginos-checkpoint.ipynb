# %%
import hepi
import smpl
import numpy as np
import hepi.madgraph as mg
import matplotlib.pyplot as plt
import hepi.resummino as rs
import time
params = [
    
          "mastercode_with_gm2.in", # LO OK
          "sps1a1000_mod.in",
          "mg.in",
          "sps1a1000_mod_mod.in",
          #"param_card_nlo.dat", # LO Broken Pipe in MG
          #"mastercode_no_gm2_mod.in", # No Mod Wrong LO, Mod broken pipe
          #"VANILLA_param_card.dat", # MG crash (broken pipe)
          #"scenarioA.in", # crash MG missing mass 23 Z
          #"scenarioB.in", # crash MG missing mass 23 Z
          "scenarioB_mod.in",
         ]
model_path="/opt/MG5_aMC_v2_7_0/models/EWKino_NLO_UFO_py3"
#model_path="/opt/MG5_aMC_v2_7_0/models/MSSMatNLO_UFO"
mg.set_path("/opt/MG5_aMC_v2_7_0/")
print (mg.get_path())
rs.set_path("~/git/resummino_test/")
print (rs.get_path())
# Out:
# /opt/MG5_aMC_v2_7_0/
# ~/git/resummino_test/

# %% [markdown]
# # LO comparison

# %%
ps = [ 
    
      (1000024,-1000024), # these fail due to stop mixing
      (1000037,-1000037),
      (1000024,-1000037),
      (1000037,-1000024),
    
      (1000022,1000022),
      (1000022,1000023),
      (1000023,1000023),
      (1000022,1000024),
      (1000022,-1000037),
    
    
    
     ]

# %% [markdown]
# ## Scale

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.LO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
        li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
        try:
            mg_dl = mg.run(li,True)
            rs_dl = rs.run(li,True,False)
            #mg_dl['LO'] = mg_dl["LO"]*2.
            rs_dl['rel_diff_LO'] = (rs_dl["LO"]-mg_dl["LO"])/rs_dl["LO"]    
        except Exception as e:
            print(e)
            continue
        hepi.scale_plot(rs_dl,["LO"],cont=False)
        hepi.scale_plot(mg_dl,["LO"],cont=True)
        smpl.plot.show()
        hepi.scale_plot(rs_dl,["rel_diff_LO"],cont=False)
        #plt.ylim([-0.1,0.1])
        smpl.plot.show()
# Out:
# ./output/66c112a67d8705a7089217637ab5de83aee299257673eb77141096340cdd90a6.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/66c112a67d8705a7089217637ab5de83aee299257673eb77141096340cdd90a6.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/66c112a67d8705a7089217637ab5de83aee299257673eb77141096340cdd90a6.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# WARNING: information about "loop [1]" is missing (full block missing) using default value: 91.188.
# WARNING: information about "mass [15]" is missing using default value: 1.777.
# WARNING: information about "decay [23]" is missing using default value: 2.4952.
# WARNING: information about "decay [24]" is missing using default value: 2.085.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_x1px1m...
# INFO:  Compiling P0_ccx_x1px1m...
# INFO:  Compiling P0_ddx_x1px1m...
# INFO:  Compiling P0_ssx_x1px1m...
# INFO:  Compiling P0_uxu_x1px1m...
# INFO:  Compiling P0_cxc_x1px1m...
# INFO:  Compiling P0_dxd_x1px1m...
# INFO:  Compiling P0_sxs_x1px1m...
# INFO:  Compiling P0_bbx_x1px1m...
# INFO:  Compiling P0_bxb_x1px1m...
# INFO:     P0_uux_x1px1m done.
# INFO:     P0_ssx_x1px1m done.
# INFO:     P0_sxs_x1px1m done.
# INFO:     P0_ccx_x1px1m done.
# INFO:     P0_ddx_x1px1m done.
# INFO:     P0_cxc_x1px1m done.
# INFO:     P0_uxu_x1px1m done.
# INFO:     P0_bbx_x1px1m done.
# INFO:     P0_dxd_x1px1m done.
# INFO:     P0_bxb_x1px1m done.
# INFO: Checking test output:
# INFO: P0_uux_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ccx_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ddx_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ssx_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_uxu_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_cxc_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_dxd_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_sxs_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bbx_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bxb_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [ current time: 12h21 ]
# INFO:
#       Results after grid setup:
#       Total cross section:      7.181e-02 +- 3.1e-04 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [ current time: 12h21 ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [ current time: 12h21 ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  0.08s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000024 -1000024 [LOonly]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 7.185e-02 +- 1.9e-04 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               7.185e-02 pb  +0.2% -0.9%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/66c112a67d8705a7089217637ab5de83aee299257673eb77141096340cdd90a6.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# 736fbf029766d20d4742543c2900b9df1dab7a58330541ab63d91d1eb391ffed
# e7eb5c71e58b9e6d54f345cd4934d59959fb0ff5abb2e6dc1abd8621f1c1607a
# e85e52cd2c6e2a1aeb21309840e55cd2a8bc356c256f874b88d45f4ffbd65afa
# ece0d3a398aa1aa47d9f90b923d366495db66ff90144122f8a388f1ddd50a8d2
# bf37b0491d9afc4db5cba1e30c9c08ff71146d4c02b96a197d89a05f58f0859a
# d48f233f168478d557b83f87d846b75df90880d02e1938415ba3b0ef90b9d105
# a3c06ebeb53f23ba6f85c39a94e9e776fe4a570cd12710b9a3d75b3155e644c6
# 9b88234de29cc0d7f898e646ea1620b41661e652368a3ff596fdf8d86de3a0da
# a1d4f9b2c4dd51001435da9f977bc2c02bfd1e5f4c68dc63c76d124a56d4313f
# 4f70998f1b99311f83cb02aca35f4352d254e817c2385e265aebad2a8ab1f9f0
# e11cb44ba56366dc74ebb0a3901f05b960fe9232c639664274ff5f3724c09e05
# d7b365b0df7a22004bd7e40b04142c29f90d9b5de43b8249c08108d7ba95d230
# 4e31bec078cca9a6a4403171f677550f502e1d251784c0a46fbc669424cd93de
# 4c938a47a6eabae5371f98d09d3f80af279bc02c60284b8beb5faeeff656eb64
# 687b5146d04046ac59816dbd450c18d244c57bb907f764e9849fab3501a259fe
# cffbadfdfd3ac731f95418fd600d073860528ac556963dbd46ff7e8eb33ee97d
# ./output/4f6ccf0fa1292596bccc24d65a447bd1d5e99b398295e760e91f0792462b3c89.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/4f6ccf0fa1292596bccc24d65a447bd1d5e99b398295e760e91f0792462b3c89.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/4f6ccf0fa1292596bccc24d65a447bd1d5e99b398295e760e91f0792462b3c89.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# WARNING: information about "loop [1]" is missing (full block missing) using default value: 91.188.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_x1px1m...
# INFO:  Compiling P0_ccx_x1px1m...
# INFO:  Compiling P0_ddx_x1px1m...
# INFO:  Compiling P0_ssx_x1px1m...
# INFO:  Compiling P0_uxu_x1px1m...
# INFO:  Compiling P0_bbx_x1px1m...
# INFO:  Compiling P0_dxd_x1px1m...
# INFO:  Compiling P0_sxs_x1px1m...
# INFO:  Compiling P0_cxc_x1px1m...
# INFO:  Compiling P0_bxb_x1px1m...
# INFO:     P0_ccx_x1px1m done.
# INFO:     P0_ddx_x1px1m done.
# INFO:     P0_dxd_x1px1m done.
# INFO:     P0_sxs_x1px1m done.
# INFO:     P0_uux_x1px1m done.
# INFO:     P0_bbx_x1px1m done.
# INFO:     P0_ssx_x1px1m done.
# INFO:     P0_uxu_x1px1m done.
# INFO:     P0_bxb_x1px1m done.
# INFO:     P0_cxc_x1px1m done.
# INFO: Checking test output:
# INFO: P0_uux_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ccx_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ddx_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ssx_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_uxu_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_cxc_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_dxd_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_sxs_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bbx_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bxb_x1px1m
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [ current time: 12h24 ]
# INFO:
#       Results after grid setup:
#       Total cross section:      4.891e-01 +- 2.2e-03 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [ current time: 12h24 ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [ current time: 12h24 ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  0.04s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  0.1s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000024 -1000024 [LOonly]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 4.897e-01 +- 1.3e-03 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               4.897e-01 pb  +3.0% -4.4%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/4f6ccf0fa1292596bccc24d65a447bd1d5e99b398295e760e91f0792462b3c89.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input''standard input': Inappropriate ioctl for device: Inappropriate ioctl for device
#
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/d9b244a1bc237d9aee61c9d9d9dc73794e13f60daa314b9b454cfef32ff6feb4.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/26c86bae2061044b6803ed1a5a3e06cbae23f0655405044de952c1f20cbc072c.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/d8e512b81612c921ee6d0c278b329eca23dcdccdcc1f2b6c3d193c6bbac4e865.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/8e3eb134f6653a86b9702a56af1abdc8316352b92f90e8a5c75c7ddd70c7200b.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/a6288f6301df72c9949ce1edac0e2087f85d8aa01eaf52caaa99f838c69fd528.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/fcaed2318ae7d6802cccd29712a8b442d3494c261305eea7b00ad6bfd849927e.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/6f854925f9831c0ac9240d942df917c9ada5278b25982299f7f81512ffb95d87.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/b9e2db96577be1fe6a2b166929e736802c6d84c31bde905a4477d3dc463963c1.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/9020a4f6a0cf2e9978920adb187f894575f73ab9d0a579f11e9371f8c5346591.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/29b7645c211e623b7936e0be83356a628cdc6e7f7edca2a532e82e04b9d5c362.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/d33e89158fe569d911077e32ad3d0eeb6d2ddc4d66cc9be99d6e5f9b806b8e31.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/b4af2abddbe6270b6a439006bd31f4449475fb659032c374db2194b234b743d0.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/4f6ccf0fa1292596bccc24d65a447bd1d5e99b398295e760e91f0792462b3c89.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/4cdf13662064adb071a432a88c431a3ec590b189571f14f7a7b41d61b050818c.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/a6b5326674645af3f0f0e9be0bd5a983cfabe224a09d8a8338dccbd89ef372bf.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7c155b76b1858c9add8df04ca5c6a7f2f595642e0a8bcf759e6520430a0b578e.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7789/1504555706.py in <module>
#       6         li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
#       7         try:
# ----> 8             mg_dl = mg.run(li,True)
#       9             rs_dl = rs.run(li,True,False)
#      10             #mg_dl['LO'] = mg_dl["LO"]*2.
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in run(params, noskip, madstr, para)
#      39 def run(params: List[Input], noskip=False,madstr=True,para=True):
#      40     rps = _queue(params, noskip,madstr)
# ---> 41     _run(rps,para)
#      42     outs = LD2DL(rps)["dic"]
#      43     results = _parse(outs)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in _run(rps, para)
#     141
#     142     # Collect statuses
# --> 143     output = [p.wait() for p in processes]
#     144     return output
#     145
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in <listcomp>(.0)
#     141
#     142     # Collect statuses
# --> 143     output = [p.wait() for p in processes]
#     144     return output
#     145
#
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1804                         if self.returncode is not None:
#    1805                             break  # Another thread waited.
# -> 1806                         (pid, sts) = self._try_wait(0)
#    1807                         # Check the pid and loop as waitpid has been known to
#    1808                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1762             """All callers to this function MUST hold self._waitpid_lock."""
#    1763             try:
# -> 1764                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1765             except ChildProcessError:
#    1766                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ## Mass

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.LO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(100,1000,16))
        rs_dl = rs.run(li,False,False)
        mg_dl = mg.run(li,False)
        rs_dl['rel_diff_LO'] = (rs_dl["LO"]-mg_dl["LO"])/rs_dl["LO"]

        hepi.mass_plot(rs_dl,"LO",pa,logy=True)
        #hepi.mass_plot(rs_dl,p,"lo",logy=True)
        hepi.mass_plot(mg_dl,"LO",pa,logy=True)
        smpl.plot.show()
        hepi.mass_plot(rs_dl,"rel_diff_LO",pa,logy=False,label="rel_diff_LO",yaxis="rel diff")
        #plt.ylim([-0.1,0.1])
        smpl.plot.show()

# %% [markdown]
# # NLO comparison

# %%
params = [
          "mastercode_with_gm2.in", # LO OK
          "scenarioB_mod.in",
          "sps1a1000_mod.in",
          "sps1a1000_mod_mod.in",
          "mg.in",
          #"param_card_nlo.dat", # LO Broken Pipe in MG
          #"mastercode_no_gm2_mod.in", # No Mod Wrong LO, Mod broken pipe
          #"VANILLA_param_card.dat", # MG crash (broken pipe)
          #"scenarioA.in", # crash MG missing mass 23 Z
          #"scenarioB.in", # crash MG missing mass 23 Z
         ]
ps = [ 
      (1000022,1000022),
      (1000035,1000035),
      (1000035,1000022),
    
      (1000024,-1000024), # LO diff
      (1000037,-1000037), # LO diff
      #(1000024,-1000037), # LO diff
      #(1000037,-1000024), # LO diff
    
      #(1000022,1000023), # MG crash # negative mass...
      #(1000023,1000023), # MG crash # negative mass...
      (1000022,1000024),
      #(1000022,-1000037),
     ]

# %% [markdown]
# ## Scale

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
        li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
        try:
            mg_dl = mg.run(li,True)
            rs_dl = rs.run(li,True,False)
            rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
        except Exception as e:
            print(e)
            continue
            
        hepi.scale_plot(rs_dl,["LO","NLO"],cont=False)
        hepi.scale_plot(mg_dl,["NLO"],cont=True)
        smpl.plot.show()
        hepi.scale_plot(rs_dl,["rel_diff_NLO"],cont=False)
        #plt.ylim([-0.1,0.1])
        smpl.plot.show()
# Out:
# ./output/d7ab0ef63b8fe7fdccd9c5c537b19f51345974b4f8838674b3f467184849724e.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/d7ab0ef63b8fe7fdccd9c5c537b19f51345974b4f8838674b3f467184849724e.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/d7ab0ef63b8fe7fdccd9c5c537b19f51345974b4f8838674b3f467184849724e.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 07h13 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  4.6s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  10.8s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  11.9s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  12.5s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  14.1s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  14.7s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  15s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  15.3s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  17.5s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      8.185e-06 +- 1.1e-07 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 07h13 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  4.2s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  5.6s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  9.2s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  9.7s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  11.4s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  11.8s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  16.5s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  19.1s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  19.8s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  21.2s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 8.170e-06 +- 6.6e-08 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               8.170e-06 pb  +6.8% -8.8%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/d7ab0ef63b8fe7fdccd9c5c537b19f51345974b4f8838674b3f467184849724e.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input'stty: : Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# cc842b425f6c9335703191f0e1f05753a378297b33d32dc62c5eeefbb697a10d
# 2bc525415325594c77c6b090e55c08bd30b5d9d222475beeeb7f387b4eef59a2
# 47c43ad9b779e731d69a540bddbc609dae758ed905fd91cd04522e20bdbd197c
# bb4d2e26f8c3384e93d0eb81c483f352a0d907e3334b78ba0cf76cdd752f2f78
# 66fb220194acd748bd9088e7c8001e5fd3201ce354a64ebfd0c7ffa5ff77f6e6
# 7c56e995e5d0c99fe219da6f04485c1038ec9ba6798030253913d380f7722393
# 3b23ca95dc65862f6102db88dd4783bf526e18e299d8f837026054f8a55bba21
# ee20b7bb563ade82a86f5b7b0a6e1ba0dc4945babed73e47b7fb335795e137aa
# d3bee4810fad8ace8c485bdd2fcece6cdef1930229ffeaf00ee49af26fa32000
# d8bb6f15632c35a098236546a14957cae07ffcde1ebd3ef6a06f19f9b9c5469c
# bc07b3c2f8b190f9a7561c041041c373b8ba6dab72b0ef46cfa1d18c5fb8836b
# b4b038c8d4b182f3027c999cb06d8631071114b1788beee0fec7dc389e508a4b
# 16dc069ec3fcf72d81a69d488169a4f1c2b0a268aaa8f19b012f2721c84d2375
# 6a79fedd2f1aae6f97f11aab2234d4755b89cc3fae8bf5177a7b7e9b31997fbc
# a7f87739a306e86202d1622ae9b6d1de3a7b8b2702049223568099f3675e2d46
# ccbeb47013d2dc05977e0da55905846e3b5c3de8bb0f378fcf0753e7e862c10d
# ./output/232b675446347c6a98f9237cc650ab3a394c3f1c664038c035bcbe4ab5b90cf4.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/232b675446347c6a98f9237cc650ab3a394c3f1c664038c035bcbe4ab5b90cf4.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/232b675446347c6a98f9237cc650ab3a394c3f1c664038c035bcbe4ab5b90cf4.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# ERROR: The width of particle 1000024 is too small for an s-channel resonance (2.48923921e-10). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# ERROR: The width of particle 1000023 is too small for an s-channel resonance (6.14181595e-11). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# write ./param_card.dat
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 07h31 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  2.3s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  2.4s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  2.8s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  2.8s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  3s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  3.3s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  3.5s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  3.5s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  3.7s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  4.4s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      2.592e-04 +- 5.6e-06 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 07h31 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.8s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3.8s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  3.9s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  4s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  4.2s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.3s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  5.1s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  5.3s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  5.3s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 2.640e-04 +- 4.8e-06 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               2.566e-04 pb  +2.5% -2.2%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/232b675446347c6a98f9237cc650ab3a394c3f1c664038c035bcbe4ab5b90cf4.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# 68905b605e4da94bfa8a3c4dbf06423433354e19c0d8526e18d79dfa090cb034
# 2514a7f92f353d7f08b77bd3ea5523ca00c47b4b02df0992f4556a08798bba3b
# e577f055392e75f1c62c8d9c33749d90484b41ab3d8eddb2064736669e9a3949
# 17a7e92fe03e59e751110e047b27f4a76847105e8941eb1844a9aa5b994d0ad2
# cc04e438377f8c6c9c45218e001fb166c72ea62608b71d2663a2a54d4ca235a5
# df90e26e0ed2bf68d4967b3304311e43399ab4f35a9f20c424742d1ffec31c56
# aa568e6422d4fbadcf1bc96bd6196739cb27b0242ba994a8b0c2a6351a537d64
# fa28735ba9e01176d61c4cbb02a562431e9400a73699bd769f22c0b44758c6f0
# 0aa4d3597db0fe08f4d1fdc675dfb121dfc34a3975a6075fc3410d5563f2f874
# f3d1490e3eb5ebaae64ba28b37061cf00fb1daf93f33c60a3291ee320fd7dae5
# 055a27d8749da539e235882084bb5a95bdf5222bad757b20394ec5ee00cf6edb
# 320e84f4ce6793f73006429002eb0586bd91e310ff968e4cbcf56aa3ef4b7798
# e39a8b03abf3b1db8b36685b680dc483944f4957e5ebceb1b7568f9e02c130e0
# 09f66c0b8f03971811c73463fa27965590e311bcca256cb65cf50406b77ec88b
# ec5517af01379829e1b4177b8ae01e9b3d512ee53557cb1a492fb0a79a0d73d3
# 4e4c6b1967503a530e7f26c4f51da0f9363981c352dbac035c28e745cddfe5e8
# ./output/3628b58ef32f9bf4a491a3531b5f31d3a626bad4d23c0b8bbfd9489a1afee4aa.out
# cp: cannot create regular file './output/3628b58ef32f9bf4a491a3531b5f31d3a626bad4d23c0b8bbfd9489a1afee4aa.bdir/Cards/param_card.dat': No such file or directory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24167/1319657209.py in <module>
#       6         li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
#       7         try:
# ----> 8             mg_dl = mg.run(li,True)
#       9             rs_dl = rs.run(li,True,False)
#      10             rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in run(params, noskip, madstr, para)
#      55 def run(params: List[Input], noskip=False,madstr=True,para=True):
#      56     rps = _queue(params, noskip,madstr)
# ---> 57     _run(rps,para)
#      58     outs = LD2DL(rps)["dic"]
#      59     results = _parse(outs)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in _run(rps, para)
#     143             ' --file {in} >> {out} && cp {slha} {bdir}/Cards/param_card.dat && cp {run} {bdir}/Cards/run_card.dat && sed -i \'s/.*= req_acc_FO/ 1 = req_acc_FO/g\' {bdir}/Cards/run_card.dat && echo "automatic_html_opening = False" >> {bdir}/Cards/amcatnlo_configuration.txt && nice -n 5 {bdir}/bin/calculate_xsect -f'
#     144         pp = subprocess.Popen(com.format(**rps[0].dic), shell=True)
# --> 145         pp.wait()
#     146     # Run commands in parallel
#     147     processes = []
#
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1804                         if self.returncode is not None:
#    1805                             break  # Another thread waited.
# -> 1806                         (pid, sts) = self._try_wait(0)
#    1807                         # Check the pid and loop as waitpid has been known to
#    1808                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1762             """All callers to this function MUST hold self._waitpid_lock."""
#    1763             try:
# -> 1764                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1765             except ChildProcessError:
#    1766                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ## Mass

# %%
for pa,pb in ps:
    for param in params:
        print(param)
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(100,1000,16))
        try:
            mg_dl = mg.run(li,True)
            rs_dl = rs.run(li,True,False)
            rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
        except Exception as e:
            print(e)
            continue

        hepi.mass_plot(rs_dl,"LO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"NLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"VNLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"P_PLUS_K",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"RNLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(mg_dl,"NLO",pa,logy=True,interpolate=False)
        smpl.plot.show()
        hepi.mass_plot(rs_dl,"rel_diff_NLO",pa,logy=False,label="rel_diff_NLO",yaxis="rel diff",interpolate=False)
        #plt.ylim([-0.1,0.1])
        smpl.plot.show()
# Out:
# mastercode_with_gm2.in
# ./output/90a550859b5dc261fc997bc7594165d81f8dc46cb7a799e965d446d926d189ee.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/90a550859b5dc261fc997bc7594165d81f8dc46cb7a799e965d446d926d189ee.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/90a550859b5dc261fc997bc7594165d81f8dc46cb7a799e965d446d926d189ee.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 07h55 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  4.3s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  4.4s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  5.2s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  5.8s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  6.1s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  6.4s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  7.1s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  7.4s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  8.1s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      6.850e-06 +- 2.3e-07 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 11,  Completed: 0 [ current time: 07h55 ]
# INFO:  Idle: 0,  Running: 10,  Completed: 1 [  2.1s  ]
# INFO:  Idle: 0,  Running: 9,  Completed: 2 [  3.1s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 3 [  4.3s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 5 [  5.9s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 7 [  6.5s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 8 [  7.5s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 9 [  9.8s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 10 [  10.4s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 11 [  12.1s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 6.949e-06 +- 1.2e-07 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               6.943e-06 pb  +19.9% -24.0%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/90a550859b5dc261fc997bc7594165d81f8dc46cb7a799e965d446d926d189ee.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input'stty: 'standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# 98b4345eeee9e503dbaaa8d6fe8cee64a85c0dba8107f000e437aed626eee848
# f33415d0b2c78b3a59cce60878899ec6174dd0c89a154ef45cffd210bc65463b
# e2c81f1760949499ef277c0a9db1e75b2164cac53ea28820dae4060a6208cbda
# c946321d5c2a36293d4a6894398ae15b2b226607904da3aa295ea7afdc2f7cba
# 04b781f6173ffb44f3f2a65f36af67e4169c1972ed6bcf9fd28127606b3b2902
# 059e6f9f105525f5cc58ac9e0de1d83600b3b7f9e15cdd40fe3407ca2f549d07
# 19fe869ea527f447efebabcff4852e2dc5290f9c15cd1a0333158224ed8911a2
# 5c13e59b910debdb8cfc537677c17126001da3b9eeb5df6d8ca5936faf011563
# 4127da58b3fb02a0d6c40bd5007372a351d6d1c8f1bc83f03bd026272837c05d
# 6adb84e8c7443cc2b6c72914db1cd021597692b6e64b02745994a470c2f5d076
# d1bd9922e7abc69edfab255890c022c26d50f92c070bf1e6a0378853d1c9421c
# 4bd44d3181e4c24f852bbd5169aa401506e42ed727ae0f2db307fda7e2bee74c
# dc1a1355da4851a133badc85e1eee6c5e9bd5abdf8b216051e1ad17be7c7a6e8
# cbdaf271033fdba0752fdef3f195616201f879137b9c14fc1ef5051c9b8c9a3a
# 95e18edddb7bcd2d3e7dbc409c6319dfdbfd31b4edd513dc941b2c59e5457ae6
# b6bf0d72a46cd3e483c8c152a7745a2188a89c26fc899da10bbb7b5b7a78f193
# scenarioB_mod.in
# ./output/92b6533ea885929b7474197e68b31ebc120663a154b1f89c865f4653e5c09564.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/92b6533ea885929b7474197e68b31ebc120663a154b1f89c865f4653e5c09564.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/92b6533ea885929b7474197e68b31ebc120663a154b1f89c865f4653e5c09564.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# ERROR: The width of particle 1000024 is too small for an s-channel resonance (2.4892392e-10). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# ERROR: The width of particle 1000023 is too small for an s-channel resonance (6.1418159e-11). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# write ./param_card.dat
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 08h12 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  4.8s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  4.9s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  5s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  5.7s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  6s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  6.2s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  6.7s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  6.7s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      3.838e-03 +- 2.1e-05 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 11,  Completed: 0 [ current time: 08h13 ]
# INFO:  Idle: 0,  Running: 10,  Completed: 1 [  3s  ]
# INFO:  Idle: 0,  Running: 9,  Completed: 2 [  4.3s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 3 [  4.6s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 4 [  4.9s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 5 [  5s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 6 [  5.6s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 7 [  5.6s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 8 [  5.7s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 9 [  6.3s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 10 [  6.4s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 11 [  6.9s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 3.831e-03 +- 1.2e-05 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               3.831e-03 pb  +2.8% -2.0%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/92b6533ea885929b7474197e68b31ebc120663a154b1f89c865f4653e5c09564.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# 6faa71a590077a454efd82a26235765964f01a57ba0c88791181b31269c074cd
# 85721817915a6243e68e8f3f922538a8a9887dd5b9af04d04d49e8e82d667b1b
# f70c62041543183666dd8daa8bf3ad576b7495f89ad23b13c444fc08e28a55ef
# 730f3a00bc66da45134bf5edd3d84eef13e9c8a35f2a56b0e5273bb2e634492e
# 66db0d90d54011a8b218c9474d3ed62b088c58a5d6fb05738ad29320d2e74b84
# 9ddd6c08df2f00b8c80c2dc1ffefdb56d1e328409bb69779c0c50ffd2ca339e2
# 28b873071d8ad19245e6e5820a16c13c4c7f1c39cf0ca5bb7f38c7da3209eb33
# 0e3a98904f44d438e4c8dcb3dbafb17180c7be7e04989f7947a6d604efd214dc
# 4061e49638b7f144359ebb7f6a924bee4d5b00b9c58d62e71d587d10d84abd64
# a52ad757c62574afaf85cc37bd49010db2e31dcf2d53a20e21bee677f817cfff
# d7a92d4877d20302ed8579d15f6fb0a79023dbfd0a476df6879fba5444e90cde
# 403de0ab44a0220cdf1011286af7ecec5054fd455efa1a61355ec741da310218
# 9fde9b98295aebdd0c70848ce69089886277fb031dc914c7ce5dff65c8a41254
# ef62f392e74ac9dba70995f2c20d3fa11f28a53c147a8159f01d83e28b12ba85
# ae30e5778e07294d0136b0c4c0b443f1bbe6a1474bc259393fe342ef276417f3
# 8b1ea6e91f2194290369fef88ed26d1675ad27aa0aff2cffe8f461d3fc1f31f3
# sps1a1000_mod.in
# ./output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 08h34 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.1s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3.2s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  3.5s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  3.5s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  4.7s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  5.2s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  5.4s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  6.4s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  8.8s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      1.143e-02 +- 1.4e-04 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 08h34 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.6s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3.7s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  4.1s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  5s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  5.1s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  5.3s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  7.2s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  7.3s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  7.3s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  8.6s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 1.135e-02 +- 9.5e-05 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               1.135e-02 pb  +2.3% -1.7%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input'stty: 'standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input'stty: : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# 'standard input'stty: 'standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# e0716d3ab948824c44d583e38cc6ea44eb36f2adcd894e0bee354efd2c0260ce
# ad02582b4cf44380eacab88888b86e2cd3f8711ac183bc3d0f084cded848a2bc
# 70df38ff290ec66441f533060a281e518065af0c17aba099b54b2e5b2525e849
# 146b230670f9c9a8684781bd4a4069b6c87346e2be287ed640412af0e98c0ee4
# 76d97ce2835263b2e9a9a4d67666b2cd408399bda6bbb24d67bb072fdfdf404d
# 247ed7ad0f0f74e525bdd15a9bf3640fd2d5dc0d5ecc6f3ae5979a22d8f4cf4f
# e97bc2deeea76021031ab185a6bfb377bfcf6b96ca96d704ab65c78381224f6a
# 6fe6a8f48856dc09ddfc33ea2148e5ae225c84bfb9bf1a24ca64056b2b449d05
# d76f57a09526e3fca54b6aebd45f1f711c6587aaa2aff89e7d16eb9f20a939ca
# 6de7e9a3aedcc385ccd28f3f312d9528cb6bd8089959c59e2ff7bc8bd32548c0
# 8b54ccbd3e2ff38d3b1e25ebcb48af94f696fd3fbfbd016deff7fd8e86884b94
# 29f841cf5f9c0a906e4a4eb53e70d389d67563fac97ed816cdcbc84b9612a9fc
# 0862c0d05e106e71373104ce2f10ae533ec76115ab9498f4ff9b0f4448c0a816
# 45955b7113ad708a362010a398d20f56517f702172d0dd6dbb6940ea52cb2499
# cd475b163cbf023d2264e832e4bed19b1f8194031f3a2d3bb1476b3fefaed401
# 1b0e9a22a98495be0898a5dc965474ea91d048e2c6edc1e2069fa4e4e6c2f7d4
# sps1a1000_mod_mod.in
# ./output/72975a92bbc219cf24060a82b3cdc9f97a04acbe2cf8e8ada71f1ce29852d1cf.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/72975a92bbc219cf24060a82b3cdc9f97a04acbe2cf8e8ada71f1ce29852d1cf.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/72975a92bbc219cf24060a82b3cdc9f97a04acbe2cf8e8ada71f1ce29852d1cf.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 08h54 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.3s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3.4s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  3.5s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  3.5s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.6s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  4.7s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  6.9s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      1.151e-03 +- 4.1e-06 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 08h54 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.8s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3.9s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  4.1s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  4.1s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.1s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  5.1s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  5.1s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  5.2s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  5.3s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 1.152e-03 +- 3.0e-06 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               1.154e-03 pb  +2.3% -2.4%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/72975a92bbc219cf24060a82b3cdc9f97a04acbe2cf8e8ada71f1ce29852d1cf.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: stty: stty: stty: 'standard input''standard input''standard input'stty: 'standard input': Inappropriate ioctl for device: Inappropriate ioctl for device
#
# : Inappropriate ioctl for device
# : Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input''standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# 22e2659b5dd6c5de9a4eaea7b161388b827ff47e12b347c307235bef395d1480
# 35c3271cf5ce86de4be6e84eb5b9ff8d367951921dec4fe1916d4d265eba311a
# 83915678684774e0099c89686039072f2f38575a2b4222164a6e4878a9cb9d73
# 3fb123e2b691bcfaab4c5398e444bbc83afe52906fcdde6af73b5dae3b3af329
# ec56f77aa047d170331ed5068de53d90f5804631d82ab46cac71b97523c0cde8
# 5adc936ceedb1d4d6d5ec2f5e4f9210ab3eab7270000bfc9f79f5ecd94ca7420
# 5a57af3aa61d5fe0922e726c558ffb4dfd8bf90452249b09853f34803804a3ae
# 7fafc48e01b51bcf6b3367d85eaa6e50922addfae7e11f69e50ee5341dec62d9
# 67ad6792c5546ded1ed560ea33dfe5250af05df0660f333f100dd34840e4ee81
# 403a5d017777d142c0779821fd69615fa6b78b3e484da608c7cdb36137931fa4
# 92b2feec562bf5110148812901ac21a05f369241cab99c8c19eb5afbde635b24
# 7fbc40b8b3f8b770ccd074ecc01a7cf336c96a30717dd2a644eba8b0634ef81b
# 4059c8ab39649e19fc659ffff2ae311e4f6baf88b95c4cfb3c7ff40b3e0b31b9
# a8aa93316398b9f6ca722d30ac7d3c2047c0a0d7569d63b6b3eb79354c44a978
# e6cc7b8d60df81c048559f10aca58d99aa792833258026c80cf035a9aea4019e
# 75b17469099abd2db91673c7f1f6ce33404b18c7ef60a464065b8d5822b21c6e
# mg.in
# ./output/d533cba51ae91b2f66d000a919f016e201185d81c0620cedc0efc29e291d6a5e.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# ...
# ERROR: The width of particle 3 is different of zero for a massless particle.
# ERROR: The width of particle 4 is different of zero for a massless particle.
# ERROR: The width of particle 5 is different of zero for a massless particle.
# ERROR: The width of particle 11 is different of zero for a massless particle.
# ERROR: The width of particle 12 is different of zero for a massless particle.
# ERROR: The width of particle 13 is different of zero for a massless particle.
# ERROR: The width of particle 14 is different of zero for a massless particle.
# ERROR: The width of particle 22 is different of zero for a massless particle.
# ERROR: The width of particle 21 is different of zero for a massless particle.
# ERROR: The width of particle 16 is different of zero for a massless particle.
# ERROR: The width of particle 9000001 is different of zero for a massless particle.
# write ./param_card.dat
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n4n4...
# INFO:  Compiling P0_ccx_n4n4...
# INFO:  Compiling P0_ddx_n4n4...
# INFO:  Compiling P0_ssx_n4n4...
# INFO:  Compiling P0_uxu_n4n4...
# INFO:  Compiling P0_cxc_n4n4...
# INFO:  Compiling P0_dxd_n4n4...
# INFO:  Compiling P0_sxs_n4n4...
# INFO:  Compiling P0_bbx_n4n4...
# INFO:  Compiling P0_bxb_n4n4...
# INFO:     P0_cxc_n4n4 done.
# INFO:     P0_uux_n4n4 done.
# INFO:     P0_bbx_n4n4 done.
# INFO:     P0_ddx_n4n4 done.
# INFO:     P0_ccx_n4n4 done.
# INFO:     P0_sxs_n4n4 done.
# INFO:     P0_bxb_n4n4 done.
# INFO:     P0_dxd_n4n4 done.
# INFO:     P0_uxu_n4n4 done.
# INFO:     P0_ssx_n4n4 done.
# INFO: Checking test output:
# INFO: P0_uux_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n4n4
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 10h52 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  2.3s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  2.4s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  3.5s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  3.8s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.1s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  4.6s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  4.9s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  4.9s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  5.4s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      2.687e-01 +- 2.0e-03 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 10h52 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.8s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  4s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  4.2s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  4.7s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  4.9s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  5.1s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  5.3s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  5.4s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  5.9s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  6.8s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000035 1000035 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 2.688e-01 +- 1.3e-03 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               2.687e-01 pb  +2.2% -1.8%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/23c687db33c94718a4ba8a6aaffe4cadb8afcd3517e9d89c2010d0280cb84625.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: stty: 'standard input''standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input'stty: stty: 'standard input''standard input'stty: 'standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# : Inappropriate ioctl for device: Inappropriate ioctl for device
#
# stty: 'standard input'stty: 'standard input': Inappropriate ioctl for device
# stty: : Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input'stty: 'standard input': Inappropriate ioctl for devicestty:
# 'standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: stty: stty: 'standard input''standard input''standard input''standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device: Inappropriate ioctl for device
# : Inappropriate ioctl for device
#
# stty: 'standard input'stty: stty: 'standard input''standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device: Inappropriate ioctl for device
#
# stty: stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 'standard input'stty: 'standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# afd13cf4d4b01a588be29c3197848625e97a920ea49194417018059b4e3a4168
# f97fef3e22e6a0b8126d238f45ba95075688966b886a9dbed083b95ef9d0f5b4
# 3def8795af51e4fdeed74f58dd91cb34eed44d528446287d9e712973e28ede1e
# 3d3c80891fcb8d08a70f89adcca20aaa6d4b39994e856aeb5a1f62220d258df9
# 7c70f53cc6b8214740fff4ae274a9dff668a20a2880936358e7e605121d573e9
# eafb3d9f278aad8f9d2de06d970636b19bf71f656070ad697aae9d4b36b02f7d
# 2cd4e115c4079903c3c945028e824e923254b40d545f450fd03b7dfda93d611e
# ed74eed8ca5d79e520d13db6dfb8dd094572bd802c7a9d1989fcaaf8b6345caf
# 824ea37f7e1bc2710bc046c76287d894e64a8245c9d257d37ae09090970787ac
# e993edf0c38c91463635485ed5248d3047d1de34c7533e74403bce953a415acc
# b36d4bac9f795ed7f883ed8b5916f0f6efb78efff9f7c269fa2644f51c0bc035
# 3d55b837d4a68067b0e1ee5ac035c1112f5018f008255f6c6ba59399f903f460
# 915d7eadfc11df5c86251ef86a9e901c08dd34abe92c5f19c811f5eb5cbdd8ee
# ebab4247da0147f4caf4137ffa173ee62c7126fd8437b6a4aaeeaf331df0e087
# 8aa919a59e505d56559b2bae6b7b6a1c56d1a7e1f057ee6da5e88aa291d93537
# f3ff0d1a7b3a123f31aba20c310ce3ce451b4eed31d481e1da629ec4057a4c9e
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to 0*5.86008380E-01.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to 8.35181765E-01.
# mastercode_with_gm2.in
# ./output/3c90fd1b4bc41e3cff03d0a0a4fedafb061b7c9b365240acee494b03df5a05d0.out
