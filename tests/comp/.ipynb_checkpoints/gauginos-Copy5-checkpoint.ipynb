# %%
import hepi
import smpl
import numpy as np
import hepi.madgraph as mg
import matplotlib.pyplot as plt
import hepi.resummino as rs
import time
params = [
    
          "sps1a1000_mod.in",
          "mg.in",
          "sps1a1000_mod_mod.in",
          #"param_card_nlo.dat", # LO Broken Pipe in MG
          #"mastercode_no_gm2_mod.in", # No Mod Wrong LO, Mod broken pipe
          "mastercode_with_gm2.in", # LO OK
          #"VANILLA_param_card.dat", # MG crash (broken pipe)
          #"scenarioA.in", # crash MG missing mass 23 Z
          #"scenarioB.in", # crash MG missing mass 23 Z
          "scenarioB_mod.in",
         ]
model_path="/opt/MG5_aMC_v2_7_0/models/EWKino_NLO_UFO_py3"
#model_path="/opt/MG5_aMC_v2_7_0/models/MSSMatNLO_UFO"
mg.set_path("/opt/MG5_aMC_v2_7_0/")
print (mg.get_path())
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
print (rs.get_path())
# Out:
# /opt/MG5_aMC_v2_7_0/
# ~/git/resummino_ug_to_UX_vNLO/

# %% [markdown]
# # LO comparison

# %%
ps = [ 
    
      (1000022,1000022),
      (1000022,1000023),
      (1000023,1000023),
      (1000022,1000024),
      (1000022,-1000037),
    
      (1000024,-1000024), # these fail due to stop mixing
      (1000037,-1000037),
      (1000024,-1000037),
      (1000037,-1000024),
     ]

# %% [markdown]
# ## Scale

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.LO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
        li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
        try:
            mg_dl = mg.run(li,False)
            rs_dl = rs.run(li,False,False)
            rs_dl['rel_diff_LO'] = (rs_dl["LO"]-mg_dl["LO"])/rs_dl["LO"]    
        except Exception as e:
            print(e)
            continue
        hepi.scale_plot(rs_dl,["LO"],cont=False)
        hepi.scale_plot(mg_dl,["LO"],cont=True)
        smpl.plot.show()
        hepi.scale_plot(rs_dl,["rel_diff_LO"],cont=False)
        #plt.ylim([-0.1,0.1])
        smpl.plot.show()
# Out:
# ./output/927b26119a400248c1f16af656e30df64668d2e78ef6b0636900f36149f198df.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/927b26119a400248c1f16af656e30df64668d2e78ef6b0636900f36149f198df.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/927b26119a400248c1f16af656e30df64668d2e78ef6b0636900f36149f198df.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# WARNING: information about "loop [1]" is missing (full block missing) using default value: 91.188.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [ current time: 07h55 ]
# INFO:
#       Results after grid setup:
#       Total cross section:      8.537e-04 +- 3.7e-06 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [ current time: 07h55 ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  0.065s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  0.081s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  0.081s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  0.097s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  0.13s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [LOonly]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 8.578e-04 +- 2.2e-06 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               8.578e-04 pb  +8.5% -10.2%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/927b26119a400248c1f16af656e30df64668d2e78ef6b0636900f36149f198df.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/dd3e7bbeabf9064af25216cf2ee609f2f6d552662d9110721c0206701a97498b.out
# Running: 16 jobs
# HASH COLLIDED ./output/ce094659bc11936276886f170c97512dc276bdebc1e9f936fe1358e25de03390.out
# HASH COLLIDED ./output/cc57e851b0eaff5ee00750660132557a8cf5cbee4111a6e1cce1491612bc80d0.out
# HASH COLLIDED ./output/00621930cb9d7c7e1649d7fecb830e9cd1c6462d0d4ce3bcca8a3938f30acab5.out
# HASH COLLIDED ./output/be809fc256f0c57553d12cee3e376f96b8f48c31703c57dc5f8556af66569c73.out
# HASH COLLIDED ./output/9f77434aa56ccfab91c1c8e740412a5f2a1976d2358b58c85fcbec12b73f8d25.out
# HASH COLLIDED ./output/da796357ebfb4ebc25d19c1230389c5c585e2e07d2c6ede575d9629638baa69f.out
# HASH COLLIDED ./output/66530b7f62aff0048b9fdd5e3676a46ba5cee860126329eddb5b050da423bbd1.out
# HASH COLLIDED ./output/12654c343e12593bd792691ec76f07ee8d5dfb76ad02e172f9799ed66c00e150.out
# HASH COLLIDED ./output/da89aa89c1ef71b0d42c5a912356ae7cadb476803683cf1f15212f4cd551585f.out
# HASH COLLIDED ./output/aaed62203643b9453c4db403d47b7c35e7f2eabbcc8267d05a05829a2e158241.out
# HASH COLLIDED ./output/7fb8dc2ce1527a7c7ab0c39f70c8d7f290a54c9d679b85a9a0eafdcb7684923c.out
# HASH COLLIDED ./output/89bd8bf7da08fdfdf5a4c44dce46570e6f6ef2db144384336bd442323cc9fd41.out
# HASH COLLIDED ./output/880b55c3e9825e91f930454184094c3ac482c3acbd8cc123da6be036596464e8.out
# HASH COLLIDED ./output/0858873579f1654889eddee5915bffa15336c5fd8160a159037d2e922d83f9fd.out
# HASH COLLIDED ./output/920ec73efe8d5b45e3a05bf18a0f11b9f80124a802f333ce9f536f62e4f41e44.out
# HASH COLLIDED ./output/05a87f7e992acdbb20fe668eb2537b0ba19d05c2e8c41e7450a84fa4227a61dc.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/c4919e0c3c692bb37c240a130660f564b1a56e8860e861ac6a74e4fb0facb2fd.out
# Running: 16 jobs
# HASH COLLIDED ./output/9da5b587459135e6c7f27a30d8424425d4885b350c2142c1ef05d3a9d3db4e24.out
# HASH COLLIDED ./output/6ef706d7dfd8b061abbadfb1beaa65c500047bb1398bb345910947f119078c47.out
# HASH COLLIDED ./output/ffd8eb450d59805e59c8a16129f3d6ea2c946055814e95c8c146ca91eb0952e1.out
# HASH COLLIDED ./output/12921dbd3ecea8179033e575e86081d74c00f697cb1edac1947b25ba9403aaac.out
# HASH COLLIDED ./output/db6fd5e1bed99dc3c85ce511e81992f75b67a1b822e9ec2261cd297808bc27f9.out
# HASH COLLIDED ./output/43abd6fe16de67f1d90083404857a37bc996d9584beac31200083252350e3cc2.out
# HASH COLLIDED ./output/fcdc3675fd25af2719aed35b23d15a22bd9415f61b438177f73ec739d7b0ecd7.out
# HASH COLLIDED ./output/8e1a8a9a2a2736abceb5c89016273346d9cb0abae6fbed30483b0c279593e6d1.out
# HASH COLLIDED ./output/b7991994183a9a513316fbd7f3d649c4e12d2b27ed4d1db0cb94dd88720af1cd.out
# HASH COLLIDED ./output/4ed87074a0d3d6d1dc7ad4cae7bd158c6de33c68988bde8e1f539a3b6fe6f000.out
# HASH COLLIDED ./output/9871865d664a5eb3f348763236fce95c1104865261542860ac03205e799deae4.out
# HASH COLLIDED ./output/aeba7283aeedc6590be8abf3af4dcb25097914c992e989df91d4aaea6c3e8ccd.out
# HASH COLLIDED ./output/127bb17d0643ba45764a379b12385526ee0182801ff70af24e4d71bcab941664.out
# HASH COLLIDED ./output/d86b003eccc9f34bf2b3a0baabbdbcf69cc855cf79a04d4bfd371a2b85e10349.out
# HASH COLLIDED ./output/6e535423d450ec3bbc07de15ba84b5936445fe76f41ee22210345e3150b6f22f.out
# HASH COLLIDED ./output/cce48dce50408fa45abbda2bafdec075effb4037641647c6d15e2871d79db859.out
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/6409681ac461d1eeb57badfcc7e9b14d0426beb2a5a0aeb699e414ff1f15c21c.out
# Running: 16 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/0a4858cebf0ba642c5f3dd9428b6bfff7adb861192d8cf6a73c904e3dcf36a21.out
# Running: 16 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# ./output/7e9b63772f6bac8548e378111aef4baaf941a9e3684ceec497e6ab6ad08ca63a.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7e9b63772f6bac8548e378111aef4baaf941a9e3684ceec497e6ab6ad08ca63a.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7e9b63772f6bac8548e378111aef4baaf941a9e3684ceec497e6ab6ad08ca63a.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# WARNING: information about "loop [1]" is missing (full block missing) using default value: 91.188.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n2...
# INFO:  Compiling P0_ccx_n1n2...
# INFO:  Compiling P0_ddx_n1n2...
# INFO:  Compiling P0_ssx_n1n2...
# INFO:  Compiling P0_uxu_n1n2...
# INFO:  Compiling P0_cxc_n1n2...
# INFO:  Compiling P0_dxd_n1n2...
# INFO:  Compiling P0_sxs_n1n2...
# INFO:  Compiling P0_bbx_n1n2...
# INFO:  Compiling P0_bxb_n1n2...
# INFO:     P0_uxu_n1n2 done.
# INFO:     P0_cxc_n1n2 done.
# INFO:     P0_dxd_n1n2 done.
# INFO:     P0_ssx_n1n2 done.
# INFO:     P0_bxb_n1n2 done.
# INFO:     P0_bbx_n1n2 done.
# INFO:     P0_ddx_n1n2 done.
# INFO:     P0_ccx_n1n2 done.
# INFO:     P0_sxs_n1n2 done.
# INFO:     P0_uux_n1n2 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ccx_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ddx_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ssx_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_uxu_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_cxc_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_dxd_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_sxs_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bbx_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bxb_n1n2
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [ current time: 07h57 ]
# INFO:
#       Results after grid setup:
#       Total cross section:      2.181e-01 +- 8.6e-04 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [ current time: 07h57 ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [ current time: 07h57 ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  0.024s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  0.14s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000023 [LOonly]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 2.197e-01 +- 5.2e-04 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               2.197e-01 pb  +4.0% -5.4%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7e9b63772f6bac8548e378111aef4baaf941a9e3684ceec497e6ab6ad08ca63a.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/d4f7613023e3f3fd6383a0e7cada30cbfe089a610c2b1699d1bdd0ea4cb3554b.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/9d5727ed2c02406271d926a49dd40c898c3b092fb2ed0691ac822b4cabc54f8c.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/65a41087898136df7ecc2f329e8ef08a9faa2716733213ab90abbbf6f47a25ee.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/a76d3767a4a66009bf151c36cce69ba4411b5fc19442caa1b323d4e3b60eed62.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/6e09df01c7c4a4dbed2cab3ea4bfe3724f91e130f7d5cb7f7c0308133bdb98c1.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2fc0042fca33cc80e6f981ce247e670ce4f27f529ae1b997246dc7b766b469f6.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/0586e9d649f35848606e471bbfcd03a012f51916fee979e9f74624010aee8b12.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7e9b63772f6bac8548e378111aef4baaf941a9e3684ceec497e6ab6ad08ca63a.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/bf804142c58fe8787fd396ee5966025fdd696acdbb8db7886a4088708e2aaa79.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/9db40cb00f7ef9c8639ef0499eca9056fac54716f18410cfecbb6f12cff2de8e.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2f8547c43fb108ea78192af601d55b7e66b12ee71f569cce93d24b0cd5602748.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/635e22a15ad4c2ceda88e5b99224ba60a7b6ae16d5f5caf486e867b9774ff27b.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/8a5c2fcde63674d22b57fc8fb3057fb1434b72f7734b546741010368bb0cb948.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/bd5b199313a7da47a7ce5f4f58570f45b9872f22e0ad00e3c5ba922039bc8e04.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/32db1bcc3ec4492230d76cf39248aa8da0f04a3b7a1c377a18f1bbeb62f87ac9.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/fe69928c310d939b901a24ce988b25d4c57553b8fb02af98b366c381c6cf6c87.dir/run_02_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# KeyboardInterrupt :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1805                             break  # Another thread waited.
# -> 1806                         (pid, sts) = self._try_wait(0)
#    1807                         # Check the pid and loop as waitpid has been known to
#
# /usr/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1763             try:
# -> 1764                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1765             except ChildProcessError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9165/4156772586.py in <module>
#       6         li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
#       7         try:
# ----> 8             mg_dl = mg.run(li,False)
#       9             rs_dl = rs.run(li,False,False)
#      10             rs_dl['rel_diff_LO'] = (rs_dl["LO"]-mg_dl["LO"])/rs_dl["LO"]
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in run(params, noskip, madstr, para)
#      39 def run(params: List[Input], noskip=False,madstr=True,para=True):
#      40     rps = _queue(params, noskip,madstr)
# ---> 41     _run(rps,para)
#      42     outs = LD2DL(rps)["dic"]
#      43     results = _parse(outs)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in _run(rps, para)
#     141
#     142     # Collect statuses
# --> 143     output = [p.wait() for p in processes]
#     144     return output
#     145
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in <listcomp>(.0)
#     141
#     142     # Collect statuses
# --> 143     output = [p.wait() for p in processes]
#     144     return output
#     145
#
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1094             self._sigint_wait_secs = 0  # nothing else should wait.
#    1095             try:
# -> 1096                 self._wait(timeout=sigint_timeout)
#    1097             except TimeoutExpired:
#    1098                 pass
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1798                         raise TimeoutExpired(self.args, timeout)
#    1799                     delay = min(delay * 2, remaining, .05)
# -> 1800                     time.sleep(delay)
#    1801             else:
#    1802                 while self.returncode is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Mass

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.LO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(1000,4000,16))
        rs_dl = rs.run(li,False,False)
        mg_dl = mg.run(li,False)
        rs_dl['rel_diff_LO'] = (rs_dl["LO"]-mg_dl["LO"])/rs_dl["LO"]

        hepi.mass_plot(rs_dl,"LO",pa,logy=True)
        #hepi.mass_plot(rs_dl,p,"lo",logy=True)
        hepi.mass_plot(mg_dl,"LO",pa,logy=True)
        smpl.plot.show()
        hepi.mass_plot(rs_dl,"rel_diff_LO",pa,logy=False,label="rel_diff_LO",yaxis="rel diff")
        #plt.ylim([-0.1,0.1])
        smpl.plot.show()

# %% [markdown]
# # NLO comparison

# %%
params = [
          #"scenarioB_mod.in",
          #"mastercode_with_gm2.in", # LO OK
          #"sps1a1000_mod.in",
          "sps1a1000_mod_mod.in",
          #"mg.in",
          #"param_card_nlo.dat", # LO Broken Pipe in MG
          #"mastercode_no_gm2_mod.in", # No Mod Wrong LO, Mod broken pipe
          #"VANILLA_param_card.dat", # MG crash (broken pipe)
          #"scenarioA.in", # crash MG missing mass 23 Z
          #"scenarioB.in", # crash MG missing mass 23 Z
         ]
ps = [ 
      (1000022,1000022),
      (1000035,1000022),
      #(1000022,1000023), # MG crash # negative mass...
      #(1000023,1000023), # MG crash # negative mass...
      (1000022,1000024),
      (1000022,-1000037),
      #(1000037,-1000037), # LO diff
      #(1000024,-1000024), # LO diff
      #(1000024,-1000037), # LO diff
      #(1000037,-1000024), # LO diff
     ]

# %% [markdown]
# ## Scale

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
        li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
        try:
            mg_dl = mg.run(li,True)
            rs_dl = rs.run(li,False,False)
            rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
        except Exception as e:
            print(e)
            continue
            
        hepi.scale_plot(rs_dl,["LO","NLO"],cont=False)
        hepi.scale_plot(mg_dl,["NLO"],cont=True)
        smpl.plot.show()
        hepi.scale_plot(rs_dl,["rel_diff_NLO"],cont=False)
        plt.ylim([-0.1,0.1])
        smpl.plot.show()
# Out:
# ./output/62085f5c9cd498afcb941498879b7e3fc50eade05c0009f2fe1095e05d86a698.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/62085f5c9cd498afcb941498879b7e3fc50eade05c0009f2fe1095e05d86a698.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/62085f5c9cd498afcb941498879b7e3fc50eade05c0009f2fe1095e05d86a698.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 18h25 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  2.8s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3.8s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  4s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.4s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  4.8s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  5.5s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  6.2s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  6.2s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      8.443e-05 +- 4.6e-07 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 18h25 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  4.1s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  4.2s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  5s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  5.4s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  5.8s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  5.9s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  6.6s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  6.8s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  7.2s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  7.3s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 8.393e-05 +- 2.8e-07 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               8.393e-05 pb  +7.2% -4.9%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/62085f5c9cd498afcb941498879b7e3fc50eade05c0009f2fe1095e05d86a698.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 16 jobs
# HASH COLLIDED ./output/70266e3eda68e199a85ae9c3e3e45cc4de1f26781fc837fc528747481cd62974.out
# HASH COLLIDED ./output/d3d4142eecf17ef21bc69ae69a1302d457833bb1937036ad3e11bad9caf6c777.out
# HASH COLLIDED ./output/4392a0dac3e45e728cdea4dfbbba4fc7f70024d0e4c025740c0c0f1be22b56e3.out
# HASH COLLIDED ./output/3864a6a125300d97ba73191b67e1b248b6feef1d59e323c91d13d50608ddda13.out
# HASH COLLIDED ./output/2087c005e24e4232959eafefcceacd9a6051f5c0ec5b883d5fc734a2c4b762be.out
# HASH COLLIDED ./output/7a37a03df3f952af05e0b84a0539774ab8359ef3627beb8b05538f58031ef0b8.out
# HASH COLLIDED ./output/2efdf84a3528881d66ec83fc1d0eee3c413e78f40e8f0e5da9cb780f9c9696af.out
# HASH COLLIDED ./output/dabc61c64ef537e86d7cf10e410cd9e072695439ab10632d0af95b7d2c2e95e4.out
# HASH COLLIDED ./output/47eefc6c4c0947540de35dea309fc8ba692ee22cf721d6ba25b476125de0d9d9.out
# HASH COLLIDED ./output/c4c4a188baf8ac8df8f9abcf701d64e4c7bea84d14f4e4449cbcfecdc9dfdd42.out
# HASH COLLIDED ./output/f4aca63330a364f23d69c6a7d6de9667facd383630a14f8398d885ec000a2b8c.out
# HASH COLLIDED ./output/cb78e85b2539a0ab3a550710fdf84b4c02578808bb6c749f9ccc170f09705a10.out
# HASH COLLIDED ./output/7bd9a74dfcb3b21bbb080266ff974fb1fcba7b2c9bec42d96f1ae3e273bef09c.out
# HASH COLLIDED ./output/ae7facbee6c09592747cd376a67c0f3438d8df093b479912fc584a6d9778c3db.out
# HASH COLLIDED ./output/d3ccb7624f246588b5fee957e9b74dd9ee9b59078567ec8605efc0df33f71806.out
# HASH COLLIDED ./output/81f0e8d25d7967f2653bfc287d9d5839c489ec5590a4ac518f230b8913acc8e5.out
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# ./output/2bca29b20b0d43e238f349f542fbd56f67a652c3965a98e961b9ee0f7f4e783b.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2bca29b20b0d43e238f349f542fbd56f67a652c3965a98e961b9ee0f7f4e783b.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2bca29b20b0d43e238f349f542fbd56f67a652c3965a98e961b9ee0f7f4e783b.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 18h42 ]
# WARNING: program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2bca29b20b0d43e238f349f542fbd56f67a652c3965a98e961b9ee0f7f4e783b.bdir/SubProcesses/P0_ddx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Terminated
# Terminated
# date: write error: Broken pipe
# Terminated
# date: write error: Broken pipe
# Terminated
# date: write error: Broken pipe
# Terminated
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  4.8s  ]
# date: write error: Broken pipe
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  4.8s  ]
# Terminated
# date: write error: Broken pipe
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.8s  ]
# Terminated
# date: write error: Broken pipe
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  4.9s  ]
# Terminated
# date: write error: Broken pipe
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  4.9s  ]
# Terminated
# date: write error: Broken pipe
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  4.9s  ]
# quit
# INFO:
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2bca29b20b0d43e238f349f542fbd56f67a652c3965a98e961b9ee0f7f4e783b.bdir/SubProcesses/P0_ddx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2bca29b20b0d43e238f349f542fbd56f67a652c3965a98e961b9ee0f7f4e783b.bdir/run_01_tag_1_debug.log'.
# Please attach this file to your report.
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/99d420258491d694fda82f41b79f1dfdda38c4b108938df9c1ca17124ff4774e.dir/SubProcesses/P0_cxc_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/99d420258491d694fda82f41b79f1dfdda38c4b108938df9c1ca17124ff4774e.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/102fd69f14288c3ec7aa1a2030b3017fd6dd2c55f69d9da604291e51cfda9f59.dir/SubProcesses/P0_uxu_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/102fd69f14288c3ec7aa1a2030b3017fd6dd2c55f69d9da604291e51cfda9f59.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2bca29b20b0d43e238f349f542fbd56f67a652c3965a98e961b9ee0f7f4e783b.dir/SubProcesses/P0_uxu_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2bca29b20b0d43e238f349f542fbd56f67a652c3965a98e961b9ee0f7f4e783b.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/54ee6706d10f07202fc4885fea4ce499ac1702084977ca08d6bcd9e027f1f250.dir/SubProcesses/P0_cxc_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/54ee6706d10f07202fc4885fea4ce499ac1702084977ca08d6bcd9e027f1f250.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7ef4f61f827c912a63e4c2acc2a8256c09512dd2e8bf93f1b020f982b21bff40.dir/SubProcesses/P0_uux_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7ef4f61f827c912a63e4c2acc2a8256c09512dd2e8bf93f1b020f982b21bff40.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7991283b062faf95290905423ec10187d446ff9579a5a1504ad03b6c64cf03b8.dir/SubProcesses/P0_bbx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7991283b062faf95290905423ec10187d446ff9579a5a1504ad03b6c64cf03b8.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2554f563b843ee19c3a5e3393d858e4c67caf1d58636814c2d088d9d7cfeeffc.dir/SubProcesses/P0_ccx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/2554f563b843ee19c3a5e3393d858e4c67caf1d58636814c2d088d9d7cfeeffc.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/dd3367e25fb2cd8fda3228537ec96f9b98c6164518838f6f548698afdeab9f62.dir/SubProcesses/P0_sxs_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/dd3367e25fb2cd8fda3228537ec96f9b98c6164518838f6f548698afdeab9f62.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/a94804c77e73cf10c56ddff8ac8c89b81868cfc76f6c4009a40eb9071fcc9e68.dir/SubProcesses/P0_sxs_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/a94804c77e73cf10c56ddff8ac8c89b81868cfc76f6c4009a40eb9071fcc9e68.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/139a6f4e6654cbdef4c67deb07845137e29c2a4f2127c2e0aedde6a3fccd802f.dir/SubProcesses/P0_ddx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/139a6f4e6654cbdef4c67deb07845137e29c2a4f2127c2e0aedde6a3fccd802f.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/914511a416046d171e096bd267909919d49ef6cba031fa368301b0b5de28f482.dir/SubProcesses/P0_sxs_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/914511a416046d171e096bd267909919d49ef6cba031fa368301b0b5de28f482.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7e7bf4a80277ea4452909a9476ff7346a6e77fda7ab1a66ba5c857822ba64a60.dir/SubProcesses/P0_ccx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7e7bf4a80277ea4452909a9476ff7346a6e77fda7ab1a66ba5c857822ba64a60.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/22f4d8a623398e05a71935f6b9f6649b4d5efd62ec9bd2d935aa1eb30de4646e.dir/SubProcesses/P0_ddx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/22f4d8a623398e05a71935f6b9f6649b4d5efd62ec9bd2d935aa1eb30de4646e.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/64b94a27515495c1462f07a6ee576e2a7cb031203a709d9e69406898a9c1cb1f.dir/SubProcesses/P0_ccx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/64b94a27515495c1462f07a6ee576e2a7cb031203a709d9e69406898a9c1cb1f.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/df8b66d15645507831c2f564b201df71fd96a269499b37156b91f5b61deb9b99.dir/SubProcesses/P0_uux_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/df8b66d15645507831c2f564b201df71fd96a269499b37156b91f5b61deb9b99.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/3389e7f9566089a97036ce9735916ee3dd7e523753cf89fe725eecc4939949b7.dir/SubProcesses/P0_ddx_n1n1/ajob1 1 all 0 0 launch ends with non zero status: 1. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/3389e7f9566089a97036ce9735916ee3dd7e523753cf89fe725eecc4939949b7.dir/run_02_tag_1_debug.log'.
# Please attach this file to your report.
# Running: 16 jobs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7483/3590373012.py in <module>
#       7         try:
#       8             mg_dl = mg.run(li,True)
# ----> 9             rs_dl = rs.run(li,False,False)
#      10             rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
#      11         except Exception as e:
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/run.py in run(params, noskip, bar, no_parse, para)
#      44     print("Running: " + str(len(params))  +" jobs" )
#      45     rps = _queue(params, noskip)
# ---> 46     _run(rps, bar, no_parse,para)
#      47     if not no_parse:
#      48         outs = LD2DL(rps)["out_path"]
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/run.py in _run(rps, bar, no_parse, para)
#     187     if not no_parse:
#     188         # Collect statuses
# --> 189         output = [p.wait() for p in processes]
#     190         return output
#     191     return []
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/run.py in <listcomp>(.0)
#     187     if not no_parse:
#     188         # Collect statuses
# --> 189         output = [p.wait() for p in processes]
#     190         return output
#     191     return []
#
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1804                         if self.returncode is not None:
#    1805                             break  # Another thread waited.
# -> 1806                         (pid, sts) = self._try_wait(0)
#    1807                         # Check the pid and loop as waitpid has been known to
#    1808                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1762             """All callers to this function MUST hold self._waitpid_lock."""
#    1763             try:
# -> 1764                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1765             except ChildProcessError:
#    1766                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ## Mass

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(100,1000,1))
        try:
            #mg_dl = mg.run(li,False)
            rs_dl = rs.run(li,True,False,True,True)
            #rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
        except Exception as e:
            print(e)
            continue
# Out:
# Running: 1 jobs
# a6eec4a6afd657ff10ed68ca6c3a65059bcdf5e6aeacaed24040c5aa6091ca8d
# Running: 1 jobs
# 70b5ccd3def78b6a0ce5dcb5b4411587559c0cf761f93c60bc364461e8c077a6
# Running: 1 jobs
# 49a82f1f7235f6d4ee591548e5dc0fbb6b95fb6258cd870973130227bbdff1ec
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# Running: 1 jobs
# 4f09eedd5410d2afef659be38288e556534af7797b79698cfa2db153c32b663c
# Running: 1 jobs
# f40d02f7d7dab01e3df088674fbf773ba1d4903dd30977a1db150f9563b4df45
# Running: 1 jobs
# 45a5e69a189d827909ffb9f280324d70359824c844ffa9f92297908de82de0eb
# Running: 1 jobs
# 607d32512c3247e9c765f3dee058df7b7b96eba57e6bc4a1e07a716f5420acd4
# Running: 1 jobs
# 57d6e725c783f030bdd6bc7fd63588a218bbec89ebf3b69483702112b28d899d
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# Running: 1 jobs
# 97cd16b88fc6af00290163a0ddcf7317f42d10190b9ace32609b3fa906a80692
# Running: 1 jobs
# ff19e9805ad8fbf7023353ec7c3a68d8328ef7c68b8e2845541c30ac294d8608
# Running: 1 jobs
# 756b31ac43fccc9ea499167d957da44c0400d4476f5be1cd954a5f5d275854a8
# Running: 1 jobs
# f34cb2e72d2c1b217e7bb6d467904005b1603b89a1ff568d8862f6b2a3a11ad2
# Running: 1 jobs
# c85c871da29aba0cc67b06fc91e9d8ce2a7fff92220eaa10bdc267b4d45f50f3
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# Running: 1 jobs
# ee4042ecc80146a66d61a94fd3d246c2b2dad598e062f017676ec1892740250c
# Running: 1 jobs
# 7b0da29326cadd5976d87cdcc685cbfd7ca78f5d1bf709260d1e978722f38bec
# Running: 1 jobs
# 9ed5edc26e2d722a411b0a7eeac6fb9639ac0ec9f0e47343f408cae649500067
# Running: 1 jobs
# b6b666da2a27255579cfe9181eb6d28fa7d1294e4a5efcdc86cb5a03283884bf
# Running: 1 jobs
# 5cd18ad89d3449b4ff84db3cba3be1c5c518bc7589bc554fd590ec93a5c81119
# warning: No Yukawa coupling Yd defined. Set to zero.
# warning: No Yukawa coupling Ys defined. Set to zero.
# warning: No Yukawa coupling Yb defined. Set to zero.
# warning: No Yukawa coupling Yu defined. Set to zero.
# warning: No Yukawa coupling Yc defined. Set to zero.
# warning: No Yukawa coupling Yt defined. Set to zero.
# Running: 1 jobs
# 5297e967acdcf6607d7feb1b5b6a4e3be05637ab28a5600fca2a634ee460eb12
# Running: 1 jobs
# 2d2db46464eb8b2c394673b8270c325a502f48cc2569d3622b9ca09bfdc24188

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(100,1000,1))
        try:
            rs_dl = rs.run(li,True,False)
            mg_dl = mg.run(li,True)
            rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
        except Exception as e:
            print(e)
            continue

        hepi.mass_plot(rs_dl,"LO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"NLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"VNLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"P_PLUS_K",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"RNLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(mg_dl,"NLO",pa,logy=True,interpolate=False)
        smpl.plot.show()
        hepi.mass_plot(rs_dl,"rel_diff_NLO",pa,logy=False,label="rel_diff_NLO",yaxis="rel diff",interpolate=False)
        #plt.ylim([-0.1,0.1])
        smpl.plot.show()
# Out:
# Running: 1 jobs
# 70b5ccd3def78b6a0ce5dcb5b4411587559c0cf761f93c60bc364461e8c077a6

# %%
for pa,pb in ps:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path)
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(100,1000,1))
        try:
            mg_dl = mg.run(li,False)
            rs_dl = rs.run(li,False,False)
            rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
        except Exception as e:
            print(e)
            continue

        hepi.mass_plot(rs_dl,"LO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"NLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"VNLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"P_PLUS_K",pa,logy=True,interpolate=False)
        hepi.mass_plot(rs_dl,"RNLO",pa,logy=True,interpolate=False)
        hepi.mass_plot(mg_dl,"NLO",pa,logy=True,interpolate=False)
        smpl.plot.show()
        hepi.mass_plot(rs_dl,"rel_diff_NLO",pa,logy=False,label="rel_diff_NLO",yaxis="rel diff",interpolate=False)
        #plt.ylim([-0.1,0.1])
        smpl.plot.show()
# Out:
# skip./output/72975a92bbc219cf24060a82b3cdc9f97a04acbe2cf8e8ada71f1ce29852d1cf.out
# Running: 1 jobs
# skip
# RESTART None None None ./output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.out
# ./output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:  Compiling P0_bbx_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_uux_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 08h39 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.3s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  3.4s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  3.5s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  3.6s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  5.2s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  6.5s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  6.5s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  10.1s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      1.143e-02 +- 1.4e-04 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 08h39 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  4.1s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  4.3s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  4.3s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  5.4s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  5.4s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  5.6s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  7.7s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  7.9s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  8s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  8.9s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 1.135e-02 +- 9.5e-05 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               1.135e-02 pb  +2.3% -1.7%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/3b2a286514c7bb5f68737763d4e8eb22196fbca15a276cfa7aaed8ac21c82005.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Running: 1 jobs
# skip
# skip./output/d533cba51ae91b2f66d000a919f016e201185d81c0620cedc0efc29e291d6a5e.out
# Running: 1 jobs
# skip
# skip./output/90a550859b5dc261fc997bc7594165d81f8dc46cb7a799e965d446d926d189ee.out
# Running: 1 jobs
# skip
# skip./output/92b6533ea885929b7474197e68b31ebc120663a154b1f89c865f4653e5c09564.out
# Running: 1 jobs
# skip
# ./output/c62013c0cb2de972887b869d67f4a265c855cd15a44f19a2c87d280ce7425e9e.out
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1805                             break  # Another thread waited.
# -> 1806                         (pid, sts) = self._try_wait(0)
#    1807                         # Check the pid and loop as waitpid has been known to
#
# /usr/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1763             try:
# -> 1764                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1765             except ChildProcessError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9165/2718376595.py in <module>
#       5         li = hepi.mass_scan([i],pa, np.linspace(100,1000,1))
#       6         try:
# ----> 7             mg_dl = mg.run(li,False)
#       8             rs_dl = rs.run(li,False,False)
#       9             rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in run(params, noskip, madstr, para)
#      39 def run(params: List[Input], noskip=False,madstr=True,para=True):
#      40     rps = _queue(params, noskip,madstr)
# ---> 41     _run(rps,para)
#      42     outs = LD2DL(rps)["dic"]
#      43     results = _parse(outs)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in _run(rps, para)
#     127             ' --file {in} >> {out} && cp {slha} {bdir}/Cards/param_card.dat && cp {run} {bdir}/Cards/run_card.dat && sed -i \'s/.*= req_acc_FO/ 1 = req_acc_FO/g\' {bdir}/Cards/run_card.dat && echo "automatic_html_opening = False" >> {bdir}/Cards/amcatnlo_configuration.txt && nice -n 5 {bdir}/bin/calculate_xsect -f'
#     128         pp = subprocess.Popen(com.format(**rps[0].dic), shell=True)
# --> 129         pp.wait()
#     130     # Run commands in parallel
#     131     processes = []
#
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1094             self._sigint_wait_secs = 0  # nothing else should wait.
#    1095             try:
# -> 1096                 self._wait(timeout=sigint_timeout)
#    1097             except TimeoutExpired:
#    1098                 pass
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1798                         raise TimeoutExpired(self.args, timeout)
#    1799                     delay = min(delay * 2, remaining, .05)
# -> 1800                     time.sleep(delay)
#    1801             else:
#    1802                 while self.returncode is None:
#
# KeyboardInterrupt:
