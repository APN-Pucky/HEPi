# %%
import hepi
import smpl
import numpy as np
import hepi.madgraph as mg
import matplotlib.pyplot as plt
import hepi.resummino as rs
import time
mg.set_path("/opt/MG5_aMC_v2_7_0/")
print (mg.get_path())
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
print (rs.get_path())
ps = [1000021]
# Out:
# /opt/MG5_aMC_v2_7_0/
# ~/git/resummino_ug_to_UX_vNLO/

# %% [markdown]
# # LO comparison

# %% [markdown]
# ## Scale

# %%
for p in ps:
    i = hepi.Input(hepi.Order.LO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"NLO_COMP")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,True,False)
    mg_dl = mg.run(li,False)
    rs_dl['rel_diff_LO'] = (rs_dl["LO"]-mg_dl["LO"])/rs_dl["LO"]
    hepi.scale_plot(rs_dl,["LO"],cont=False)
    hepi.scale_plot(mg_dl,["LO"],cont=True)
    smpl.plot.show()
    hepi.scale_plot(rs_dl,["rel_diff_LO"],cont=False)
    plt.ylim([-0.1,0.1])
    smpl.plot.show()
# Out:
# Running: 16 jobs
# ./output/7d184e4a840cc538b90c0ed54f94ae31680baa9ec8b8ca80160915d5dde178fd.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7d184e4a840cc538b90c0ed54f94ae31680baa9ec8b8ca80160915d5dde178fd.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7d184e4a840cc538b90c0ed54f94ae31680baa9ec8b8ca80160915d5dde178fd.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# ERROR: The width of particle 1000024 is too small for an s-channel resonance (3.07314162e-12). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# ERROR: The width of particle 1000023 is too small for an s-channel resonance (6.67434232e-15). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# INFO: For gauge cancellation, the width of 'go' has been set to zero.
# WARNING: information about "decay [23]" is missing using default value: 2.4952.
# WARNING: information about "decay [24]" is missing using default value: 2.085.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1go...
# INFO:  Compiling P0_ccx_n1go...
# INFO:  Compiling P0_ddx_n1go...
# INFO:  Compiling P0_ssx_n1go...
# INFO:  Compiling P0_uxu_n1go...
# INFO:  Compiling P0_cxc_n1go...
# INFO:  Compiling P0_dxd_n1go...
# INFO:  Compiling P0_sxs_n1go...
# INFO:  Compiling P0_bbx_n1go...
# INFO:  Compiling P0_bxb_n1go...
# INFO:     P0_ddx_n1go done.
# INFO:     P0_uux_n1go done.
# INFO:     P0_uxu_n1go done.
# INFO:     P0_cxc_n1go done.
# INFO:     P0_ccx_n1go done.
# INFO:     P0_ssx_n1go done.
# INFO:     P0_sxs_n1go done.
# INFO:     P0_bxb_n1go done.
# INFO:     P0_bbx_n1go done.
# INFO:     P0_dxd_n1go done.
# INFO: Checking test output:
# INFO: P0_uux_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ccx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ddx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ssx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_uxu_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_cxc_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_dxd_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_sxs_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bbx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bxb_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [ current time: 06h53 ]
# INFO:
#       Results after grid setup:
#       Total cross section:      1.511e-04 +- 8.7e-07 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [ current time: 06h53 ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  0.52s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000021 1000022 [LOonly]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 1.520e-04 +- 5.4e-07 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               1.520e-04 pb  +28.3% -20.5%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/7d184e4a840cc538b90c0ed54f94ae31680baa9ec8b8ca80160915d5dde178fd.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device

# %% [markdown]
# ## Mass

# %%
for p in ps:
    i = hepi.Input(hepi.Order.LO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"NLO_COMP_MASS")
    li = [i]
    li = hepi.mass_scan([i],p, np.linspace(1000,4000,16),diff_L_R=None)
    rs_dl = rs.run(li,True,False)
    mg_dl = mg.run(li,False)
    rs_dl['rel_diff_LO'] = (rs_dl["LO"]-mg_dl["LO"])/rs_dl["LO"]
    
    hepi.mass_plot(rs_dl,"LO",p,logy=True)
    #hepi.mass_plot(rs_dl,p,"lo",logy=True)
    hepi.mass_plot(mg_dl,"LO",p,logy=True)
    smpl.plot.show()
    hepi.mass_plot(rs_dl,"rel_diff_LO",p,logy=False,label="rel_diff_LO",yaxis="rel diff")
    plt.ylim([-0.1,0.1])
    smpl.plot.show()
# Out:
# Running: 16 jobs
# ./output/5c0b462563d1aa66b3166bc6d1c37ce8776c89066f94ad937a812b665a5fc90f.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/5c0b462563d1aa66b3166bc6d1c37ce8776c89066f94ad937a812b665a5fc90f.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/5c0b462563d1aa66b3166bc6d1c37ce8776c89066f94ad937a812b665a5fc90f.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# ERROR: The width of particle 1000024 is too small for an s-channel resonance (3.0731416e-12). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# ERROR: The width of particle 1000023 is too small for an s-channel resonance (6.6743423e-15). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# INFO: For gauge cancellation, the width of 'go' has been set to zero.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1go...
# INFO:  Compiling P0_ccx_n1go...
# INFO:  Compiling P0_ddx_n1go...
# INFO:  Compiling P0_ssx_n1go...
# INFO:  Compiling P0_uxu_n1go...
# INFO:  Compiling P0_cxc_n1go...
# INFO:  Compiling P0_dxd_n1go...
# INFO:  Compiling P0_sxs_n1go...
# INFO:  Compiling P0_bbx_n1go...
# INFO:  Compiling P0_bxb_n1go...
# INFO:     P0_cxc_n1go done.
# INFO:     P0_sxs_n1go done.
# INFO:     P0_uux_n1go done.
# INFO:     P0_ssx_n1go done.
# INFO:     P0_ccx_n1go done.
# INFO:     P0_uxu_n1go done.
# INFO:     P0_dxd_n1go done.
# INFO:     P0_bxb_n1go done.
# INFO:     P0_ddx_n1go done.
# INFO:     P0_bbx_n1go done.
# INFO: Checking test output:
# INFO: P0_uux_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ccx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ddx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_ssx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_uxu_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_cxc_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_dxd_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_sxs_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bbx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: P0_bxb_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [ current time: 06h59 ]
# INFO:
#       Results after grid setup:
#       Total cross section:      5.940e-04 +- 3.4e-06 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [ current time: 06h59 ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000021 1000022 [LOonly]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 5.988e-04 +- 2.1e-06 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               5.988e-04 pb  +19.1% -15.1%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/5c0b462563d1aa66b3166bc6d1c37ce8776c89066f94ad937a812b665a5fc90f.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: stty: 'standard input''standard input'stty: : Inappropriate ioctl for device: Inappropriate ioctl for device
#
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input'stty: 'standard input'stty: 'standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: stty: 'standard input''standard input': Inappropriate ioctl for device: Inappropriate ioctl for device
#
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input'stty: : Inappropriate ioctl for device'standard input'
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input'stty: 'standard input': Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# computed AUC using sklearn.metrics.auc: 0.2570042489435405
# computed AUC using sklearn.metrics.auc: 0.2566456292773741
# computed AUC using sklearn.metrics.auc: 5.786334452808182

# %% [markdown]
# # NLO comparison

# %% [markdown]
# ## Scale

# %%
for p in ps:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"NLO_COMP")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,True,False)
    mg_dl = mg.run(li,True)
    rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
    hepi.scale_plot(rs_dl,["LO","NLO"],cont=False)
    hepi.scale_plot(mg_dl,["NLO"],cont=True)
    smpl.plot.show()
    hepi.scale_plot(rs_dl,["rel_diff_NLO"],cont=False)
    plt.ylim([-0.1,0.1])
    smpl.plot.show()
# Out:
# Running: 16 jobs
# ./output/da284886cb30a43329cefccdfeec444eebf07dfadc6235c820c9b5ba4e0cf1aa.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/da284886cb30a43329cefccdfeec444eebf07dfadc6235c820c9b5ba4e0cf1aa.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/da284886cb30a43329cefccdfeec444eebf07dfadc6235c820c9b5ba4e0cf1aa.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# ERROR: The width of particle 1000024 is too small for an s-channel resonance (3.07314162e-12). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# ERROR: The width of particle 1000023 is too small for an s-channel resonance (6.67434232e-15). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# INFO: For gauge cancellation, the width of 'go' has been set to zero.
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1go...
# INFO:  Compiling P0_ccx_n1go...
# INFO:  Compiling P0_ddx_n1go...
# INFO:  Compiling P0_ssx_n1go...
# INFO:  Compiling P0_uxu_n1go...
# INFO:  Compiling P0_cxc_n1go...
# INFO:  Compiling P0_dxd_n1go...
# INFO:  Compiling P0_sxs_n1go...
# INFO:  Compiling P0_bbx_n1go...
# INFO:  Compiling P0_bxb_n1go...
# INFO:     P0_bbx_n1go done.
# INFO:     P0_cxc_n1go done.
# INFO:     P0_uxu_n1go done.
# INFO:     P0_uux_n1go done.
# INFO:     P0_sxs_n1go done.
# INFO:     P0_dxd_n1go done.
# INFO:     P0_ssx_n1go done.
# INFO:     P0_ccx_n1go done.
# INFO:     P0_bxb_n1go done.
# INFO:     P0_ddx_n1go done.
# INFO: Checking test output:
# INFO: P0_uux_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 07h16 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.6s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  4.5s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  5.3s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  6.6s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  6.7s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  7s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  20.2s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  23.9s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      1.407e-04 +- 3.2e-06 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 07h16 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.5s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3.6s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  3.9s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  4.5s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  4.8s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.9s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  5.1s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  7s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  8s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  28.5s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000021 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 1.382e-04 +- 3.7e-06 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               1.320e-04 pb  +4.8% -7.3%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/da284886cb30a43329cefccdfeec444eebf07dfadc6235c820c9b5ba4e0cf1aa.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: stty: stty: stty: stty: stty: 'standard input''standard input''standard input''standard input''standard input''standard input'stty: : Inappropriate ioctl for device: Inappropriate ioctl for device: Inappropriate ioctl for device
#
#
# : Inappropriate ioctl for device'standard input': Inappropriate ioctl for device
#
# : Inappropriate ioctl for device
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input'stty: stty: 'standard input''standard input': Inappropriate ioctl for device: Inappropriate ioctl for device
#
# : Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device

# %% [markdown]
# ## Mass

# %%
for p in ps:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"NLO_COMP_MASS")
    li = [i]
    li = hepi.mass_scan([i],p, np.linspace(1000,4000,16),diff_L_R=None)
    rs_dl = rs.run(li,True,False)
    mg_dl = mg.run(li,True)
    rs_dl['rel_diff_NLO'] = (rs_dl["NLO"]-mg_dl["NLO"])/rs_dl["NLO"]
    
    hepi.mass_plot(rs_dl,"LO",p,logy=True)
    hepi.mass_plot(rs_dl,"NLO",p,logy=True)
    hepi.mass_plot(mg_dl,"NLO",p,logy=True)
    smpl.plot.show()
    hepi.mass_plot(rs_dl,"rel_diff_NLO",p,logy=False,label="rel_diff_NLO",yaxis="rel diff")
    plt.ylim([-0.1,0.1])
    smpl.plot.show()
# Out:
# Running: 16 jobs
# ./output/a68fb8ccee0c0c53627c64a84bd99977dd3ba5cc324d03c64c3fc76df54ebdc8.out
# No module named madgraph
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3               20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/a68fb8ccee0c0c53627c64a84bd99977dd3ba5cc324d03c64c3fc76df54ebdc8.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_0/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/a68fb8ccee0c0c53627c64a84bd99977dd3ba5cc324d03c64c3fc76df54ebdc8.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "gv". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# ERROR: The width of particle 1000024 is too small for an s-channel resonance (3.0731416e-12). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# ERROR: The width of particle 1000023 is too small for an s-channel resonance (6.6743423e-15). If you have this particle in an s-channel, this is likely to create numerical instabilities .
# INFO: For gauge cancellation, the width of 'go' has been set to zero.
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 16 cores
# INFO:  Compiling P0_uux_n1go...
# INFO:  Compiling P0_ccx_n1go...
# INFO:  Compiling P0_ddx_n1go...
# INFO:  Compiling P0_ssx_n1go...
# INFO:  Compiling P0_cxc_n1go...
# INFO:  Compiling P0_uxu_n1go...
# INFO:  Compiling P0_dxd_n1go...
# INFO:  Compiling P0_sxs_n1go...
# INFO:  Compiling P0_bbx_n1go...
# INFO:  Compiling P0_bxb_n1go...
# INFO:     P0_ddx_n1go done.
# INFO:     P0_dxd_n1go done.
# INFO:     P0_ssx_n1go done.
# INFO:     P0_uxu_n1go done.
# INFO:     P0_cxc_n1go done.
# INFO:     P0_ccx_n1go done.
# INFO:     P0_uux_n1go done.
# INFO:     P0_sxs_n1go done.
# INFO:     P0_bbx_n1go done.
# INFO:     P0_bxb_n1go done.
# INFO: Checking test output:
# INFO: P0_uux_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 16 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 09h17 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  2.9s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  4.6s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.6s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  6s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  6.7s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  7.6s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  7.7s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      9.518e-04 +- 2.0e-05 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 0,  Running: 10,  Completed: 0 [ current time: 09h17 ]
# INFO:  Idle: 0,  Running: 9,  Completed: 1 [  3.1s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  3.2s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  3.3s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  3.5s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  4.3s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  4.3s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  7.9s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  14.4s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  14.4s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000021 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 9.884e-04 +- 4.9e-05 pb
#    --------------------------------------------------------------
#       Scale variation (computed from histogram information):
#           Dynamical_scale_choice 0 (envelope of 9 values):
#               9.921e-04 pb  +11.5% -10.1%
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/comp/output/a68fb8ccee0c0c53627c64a84bd99977dd3ba5cc324d03c64c3fc76df54ebdc8.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# computed AUC using sklearn.metrics.auc: 0.2570042489435405
# computed AUC using sklearn.metrics.auc: 0.40279465836639694
# computed AUC using sklearn.metrics.auc: 0.39687170822077206
# computed AUC using sklearn.metrics.auc: 21.69026567347053
