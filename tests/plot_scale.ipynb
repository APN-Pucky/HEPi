# %%
import hepi
import smpl
import numpy as np
import hepi.resummino as rs
import matplotlib.pyplot as plt
import time
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
print (rs.get_path())
# Out:
# ~/git/resummino_ug_to_UX_vNLO/

# %%
#time.sleep(60*60*0.5)
for p in [1000002,2000002]:
    i = hepi.Input(hepi.Order.NLO_PLUS_NLL,13000,p,1000022,"mastercode.in","CT14lo","CT14nlo",1., 1.)
    li = hepi.scan([i],"mu_f",np.logspace(np.log10(1/2.), np.log10(2), 3))
    li = hepi.scan(li,"mu_r",np.logspace(np.log10(1/2.), np.log10(2), 3))
    dll = rs.run(li)
    hepi.scale_plot(dll,["lo","nlo","nlo_plus_nll"],seven_point_band=True)
    plt.savefig("scale_variation_" + str(p) + ".pdf")
# Out:
# skipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_PLUS_NLL_energy_13000_particle1_1000002_particle2_1000022_slha_mastercode.in_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.5_mu_r_0.5_id_.out</pre>
#   </div>
# </div>
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_PLUS_NLL_energy_13000_particle1_2000002_particle2_1000022_slha_mastercode.in_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.5_mu_r_0.5_id_.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.5                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.0                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0 ... 1.0                    Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0 ... 2.0                    Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.0                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.0 ... 1.0                    Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.0 ... 2.0                    Stage: DONE                     Status DONE:                    </pre>
#   </div>
# </div>

# %%
for p in [2000002,1000002]: 
    i = hepi.Input(hepi.Order.NLO_PLUS_NLL,13000,p,1000022,"mastercode.in","CT14lo","CT14nlo",1., 1.)
    li = hepi.scan([i],"mu_f",np.logspace(-1, 1, 4))
    li = hepi.scan(li,"mu_r",np.logspace(-1, 1, 4))
    dll = rs.run(li,True)
    #hepi.scale_plot(dll,["lo","nlo"])
    hepi.scale_plot(dll,["lo","nlo","nlo_plus_nll"])
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_PLUS_NLL_energy_13000_particle1_2000002_particle2_1000022_slha_mastercode.in_pdf_lo_CT14lo_pdf_nlo_CT14nlo_mu_f_0.1_mu_r_0.1_id_.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                      Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0 ... 1.0                    Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0 ... 10.0                   Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                      Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 1.0                   Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                   Stage: DONE                    Status DONE:                    </pre>
#   </div>
# </div>
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_PLUS_NLL_energy_13000_particle1_1000002_particle2_1000022_slha_mastercode.in_pdf_lo_CT14lo_pdf_nlo_CT14nlo_mu_f_0.1_mu_r_0.1_id_.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                      Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0                      Stage: DONE                        Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0 ... 1.0                    Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 1.0 ... 10.0                   Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                      Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 1.0                   Stage: DONE                     Status DONE:                    </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                   Stage: DONE                    Status DONE:                    </pre>
#   </div>
# </div>

# %%
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_mastercode.in_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_.out</pre>
#   </div>
# </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-944daa2a1129> in <module>
#       3     li = hepi.scan([i],"mu_f",np.logspace(-1, 1, 4))
#       4     li = hepi.scan(li,"mu_r",np.logspace(-1, 1, 4))
# ----> 5     dll = rs.run(li)
#       6     hepi.scale_plot(dll,["lo","nlo"])
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/run.py in run(params, noskip)
#      39     _run(rps)
#      40     outs = LD2DL(rps)["out_path"]
# ---> 41     results = _parse(outs)
#      42     rdl = LD2DL(results)
#      43     pdl = LD2DL(params)
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/run.py in _parse(outputs)
#      48     rsl = []
#      49     for f in outputs:
# ---> 50         res = parse_single(f)
#      51         rsl.append(res)
#      52     return rsl
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/result.py in parse_single(file)
#      62                     tmp.group(1).replace("+-", "+/-"))
#      63
# ---> 64     return ResumminoResult(lo_result, nlo_result, nll_result, vnlo_result, ppk_result, rnlog_result, rnloq_result)
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/result.py in __init__(self, lo, nlo, nlo_plus_nll, vnlo, p_plus_k, rnlog, rnloq)
#       6 class ResumminoResult(Result):
#       7     def __init__(self, lo, nlo, nlo_plus_nll, vnlo, p_plus_k, rnlog, rnloq):
# ----> 8         Result.__init__(self, lo, nlo, nlo_plus_nll)
#       9         self.vnlo = vnlo
#      10         self.p_plus_k = p_plus_k
#
# ~/.local/lib/python3.8/site-packages/hepi/results.py in __init__(self, lo, nlo, nlo_plus_nll)
#      11         self.nlo_plus_nll = nlo_plus_nll
#      12         self.K_lo = lo/lo
# ---> 13         self.K_nlo = nlo/lo
#      14         self.K_nlo_plus_nll = nlo_plus_nll/lo
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'Variable'
