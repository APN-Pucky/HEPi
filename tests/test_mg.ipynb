# %%
import hepi
import smpl
import numpy as np
import hepi.madgraph as mg
import hepi.resummino as rs
import matplotlib.pyplot as plt
import time
print (mg.get_path())
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
print (rs.get_path())
# Out:
# /opt/MG5_aMC_v2_7_0/
# ~/git/resummino_ug_to_UX_vNLO/

# %%
for p in [1000021]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"ISTR1_DR")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,True)
    mg_dl = mg.run(li,False)
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out

# %%
for p in [2000002,1000002,1000021]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"ISTR1_DR")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,False)
    mg_dl = mg.run(li,False)
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out

# %%
for p in [2000002,1000002,1000021]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"ISTR1_DR")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,False)
    mg_dl = mg.run(li,False)
    rs_dl["diff_nlo"] = (mg_dl["nlo"]-rs_dl["nlo"])/rs_dl["lo"]
    hepi.scale_plot(rs_dl,["lo","diff_nlo"],cont=False)
    #hepi.scale_plot(mg_dl,["nlo"],cont=True)
# Out:
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"ISTR1_DR")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,True)
    mg_dl = mg.run(li,False)
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# ./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out

# %%
for p in [2000002,1000002]:
    i = hepi.Input(hepi.Order.NLO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"ISTR1_DR")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    rs_dl = rs.run(li,True)
    mg_dl = mg.run(li,False)
    hepi.scale_plot(rs_dl,["lo","nlo"],cont=False)
    hepi.scale_plot(mg_dl,["nlo"],cont=True)
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_2000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_RS.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.1                       Stage: DONE                       Status DONE:                       </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 0.46 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 2.15 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0                       Stage: DONE                       Status DONE:                      </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 0.46                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 2.15                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 10.0 ... 10.0                    Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
# skipskipskipskipskipskipskipskipskipskipskipskipskipskipskipskip./output/order_Order.NLO_energy_13000_particle1_1000002_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_ISTR1_DR_code_MG.out
