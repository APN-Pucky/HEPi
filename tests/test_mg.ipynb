# %%
import hepi
import smpl
import numpy as np
import hepi.madgraph as mg
import matplotlib.pyplot as plt
import time
print (mg.get_path())
# Out:
# /opt/MG5_aMC_v2_7_0/

# %%
for p in [1000021]:
    i = hepi.Input(hepi.Order.LO,13000,p,1000022,"param_card_nlo.dat","CT14lo","CT14lo",1., 1.,"LO_TEST")
    li = [i]
    li = hepi.scan(li,"mu_f",np.around(np.logspace(-1, 1, 4),2))
    li = hepi.scan(li,"mu_r",np.around(np.logspace(-1, 1, 4),2))
    dll = mg.run(li,True)
    hepi.scale_plot(dll,["lo"])
# Out:
# ./output/order_Order.LO_energy_13000_particle1_1000021_particle2_1000022_slha_param_card_nlo.dat_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_0.1_mu_r_0.1_id_LO_TEST_code_MG.out
