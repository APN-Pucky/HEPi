# %%
import hepi
import smpl
import hepi.resummino as rs
import numpy as np
import matplotlib.pyplot as plt
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
print (rs.get_path())
from smpl import plot

for run_plot in [True,False]:
    for scenario in ["sps1a1000_mod.in"]:
        for lo_pdf,nlo_pdf in [("cteq66","cteq66")]:
            for p in [2000002, 1000002]:
                i = hepi.Input(hepi.Order.NLO, 7000, p, 1000022, scenario, lo_pdf, nlo_pdf, 1., 1.,precision=0.01,max_iters=50)

                li = hepi.mass_scan([i], p, np.linspace(300, 950, 14), diff_L_R=20)
                #li = hepi.seven_point_scan(li)
                #li = hepi.pdf_scan(li)

                dl = rs.run(li, False, True, run_plot)


                if not run_plot:
                    #dl = hepi.pdf_error(li,dl)
                    #dl = hepi.scale_error(li,dl)
                    #dl = hepi.combine_errors(dl)

                    hepi.mass_and_K_plot(dl,li,p,plehn=True,figsize=(6,8),interpolate=True,plot_data=False,fill=False,scenario="SPS1a$_{1000}$")
                    #plt.savefig(input.get_output_dir()+ get_job_name()+"_comp_" + nlo_pdf + "_" + str(p) + ".pdf")

                    #hepi.tex_table(dl,"mass_"+str(p),input.get_output_dir() + get_job_name()+"_mass" + str(p)+  "_"+ str(nlo_pdf) + "_" +str(scenario) + ".tex")
    #wait()
# Out:
# ~/git/resummino_ug_to_UX_vNLO/
# Running: 14 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/692583180d35f50b222a91efbb0c67e950259bf6e33ed88cb4a33fa9ce7b8940.out                       </pre>
#   </div>
# </div>
# Running: 14 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/85344ed0d5d78cd9fe4de3d5a721f32554979fc846d3e98601466de9d295bc3e.out                       </pre>
#   </div>
# </div>
# Running: 14 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/692583180d35f50b222a91efbb0c67e950259bf6e33ed88cb4a33fa9ce7b8940.out                       </pre>
#   </div>
# </div>
# Running: 14 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/85344ed0d5d78cd9fe4de3d5a721f32554979fc846d3e98601466de9d295bc3e.out                       </pre>
#   </div>
# </div>

# %%
import hepi
import smpl
import hepi.resummino as rs
import numpy as np
import matplotlib.pyplot as plt
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
print (rs.get_path())
from smpl import plot

for run_plot in [True,False]:
    for scenario in ["sps1a1000_mod.in"]:
        for lo_pdf,nlo_pdf in [("cteq6l1","cteq66")]:
            for p in [2000002, 1000002]:
                i = hepi.Input(hepi.Order.NLO_PLUS_NLL, 7000, p, 1000022, scenario, lo_pdf, nlo_pdf, 1., 1.,precision=0.01,max_iters=50)

                li = hepi.mass_scan([i], p, np.linspace(300, 950, 14), diff_L_R=20)
                #li = hepi.seven_point_scan(li)
                #li = hepi.pdf_scan(li)

                dl = rs.run(li, False, True, run_plot)


                if not run_plot:
                    #dl = hepi.pdf_error(li,dl)
                    #dl = hepi.scale_error(li,dl)
                    #dl = hepi.combine_errors(dl)

                    hepi.mass_and_K_plot(dl,li,p,plehn=True,figsize=(6,8),interpolate=True,plot_data=False,fill=False,scenario="SPS1a$_{1000}$")
                    #plt.savefig(input.get_output_dir()+ get_job_name()+"_comp_" + nlo_pdf + "_" + str(p) + ".pdf")

                    #hepi.tex_table(dl,"mass_"+str(p),input.get_output_dir() + get_job_name()+"_mass" + str(p)+  "_"+ str(nlo_pdf) + "_" +str(scenario) + ".tex")
    #wait()
# Out:
# ~/git/resummino_ug_to_UX_vNLO/
# Running: 14 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/8752160a95c73482c7e72daabc556c31bd0a4cb0b5a5b7f884b6754069108dde.out                       </pre>
#   </div>
# </div>
# Running: 14 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/ae01d9c603ba1132df07292c32920e6bb18221cce6363c7c2d126881b93e2de6.out                       </pre>
#   </div>
# </div>
# Running: 14 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/8752160a95c73482c7e72daabc556c31bd0a4cb0b5a5b7f884b6754069108dde.out                       </pre>
#   </div>
# </div>
# Running: 14 jobs
# skipskipskipskipskipskipskipskipskipskipskipskipskipskip
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/ae01d9c603ba1132df07292c32920e6bb18221cce6363c7c2d126881b93e2de6.out                       </pre>
#   </div>
# </div>
