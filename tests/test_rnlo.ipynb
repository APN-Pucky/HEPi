# %%
import hepi
import smpl
import hepi.resummino as rs
rs.set_path("~/git/resummino_rnlo/")
print (rs.get_path())
# Out:
# ~/git/resummino_rnlo/

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo2")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_13d24cf5")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_13d24cf5_rm_doubles")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_13d24cf5_rm_doubles_fix_sign")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_13d24cf5_rm_doubles_fix_sign_Kflip")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_680c7fbf")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_680c7fbf_K_noflip")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_680c7fbf")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_rnlo/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_680c7fbf")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_680c7fbf")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_fixeddd")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","cteq6l1","cteq6l1",1., 1.,"test_rnlo_fixeddd")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")

# %%
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
i = hepi.Input(hepi.Order.NLO,7000,1000002,1000022,"sps1a1000.in","cteq6l1","cteq6l1",1., 1.,"test_rnlo_fixeddd")
li = hepi.mass_scan([i],1000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,1000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,1000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,1000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,1000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a29bc5a0b15b> in <module>
#       2 i = hepi.Input(hepi.Order.NLO,7000,1000002,1000022,"sps1a1000.in","cteq6l1","cteq6l1",1., 1.,"test_rnlo_fixeddd")
#       3 li = hepi.mass_scan([i],1000002, range(300,1000,50),diff_L_R=20)
# ----> 4 dll = rs.run(li,True)
#       5 hepi.mass_plot(dll,1000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
#       6 hepi.mass_plot(dll,1000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/run.py in run(params, noskip)
#      37     _run(rps)
#      38     outs = LD2DL(rps)["out_path"]
# ---> 39     results = _parse(outs)
#      40     rdl = LD2DL(results)
#      41     pdl = LD2DL(params)
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/run.py in _parse(outputs)
#      46     rsl = []
#      47     for f in outputs:
# ---> 48         res = parse_single(f)
#      49         rsl.append(res)
#      50     return rsl
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/result.py in parse_single(file)
#      62                     tmp.group(1).replace("+-", "+/-"))
#      63
# ---> 64     return ResumminoResult(lo_result, nlo_result, nll_result, vnlo_result, ppk_result, rnlog_result, rnloq_result)
#
# ~/.local/lib/python3.8/site-packages/hepi/resummino/result.py in __init__(self, lo, nlo, nlo_plus_nll, vnlo, p_plus_k, rnlog, rnloq)
#       6 class ResumminoResult(Result):
#       7     def __init__(self, lo, nlo, nlo_plus_nll, vnlo, p_plus_k, rnlog, rnloq):
# ----> 8         Result.__init__(self, lo, nlo, nlo_plus_nll)
#       9         self.vnlo = vnlo
#      10         self.p_plus_k = p_plus_k
#
# ~/.local/lib/python3.8/site-packages/hepi/results.py in __init__(self, lo, nlo, nlo_plus_nll)
#      11         self.nlo_plus_nll = nlo_plus_nll
#      12         self.K_lo = lo/lo
# ---> 13         self.K_nlo = nlo/lo
#      14         self.K_nlo_plus_nll = nlo_plus_nll/lo
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'Variable'

# %%
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
i = hepi.Input(hepi.Order.NLO,7000,1000002,1000022,"sps1a1000.in","cteq6l1","cteq6l1",1., 1.,"test_rnlo_QQ")
li = hepi.mass_scan([i],1000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,1000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,1000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,1000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,1000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_7000_particle1_1000002_particle2_1000022_slha_sps1a1000.in_1000002_300_pdf_lo_cteq6l1_pdf_nlo_cteq6l1_mu_f_1.0_mu_r_1.0_id_test_rnlo_QQ_mass_1000002_300.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 300 ... 300.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 350 ... 350.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 400 ... 400.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 450 ... 450.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 500 ... 500.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 550 ... 550.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 600 ... 600.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 650 ... 650.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 700 ... 700.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 750 ... 750.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 800 ... 800.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 850 ... 850.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 900 ... 900.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 950 ... 950.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>

# %%
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
i = hepi.Input(hepi.Order.NLO,7000,1000002,1000022,"sps1a1000.in","CT14lo","CT14lo",1., 1.,"test_rnlo_QQ")
li = hepi.mass_scan([i],1000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,1000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,1000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,1000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,1000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_7000_particle1_1000002_particle2_1000022_slha_sps1a1000.in_1000002_300_pdf_lo_CT14lo_pdf_nlo_CT14lo_mu_f_1.0_mu_r_1.0_id_test_rnlo_QQ_mass_1000002_300.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 300 ... 300.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 350 ... 350.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 400 ... 400.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 450 ... 450.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 500 ... 500.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 550 ... 550.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 600 ... 600.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 650 ... 650.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 700 ... 700.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 750 ... 750.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 800 ... 800.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 850 ... 850.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 900 ... 900.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 950 ... 950.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>

# %%
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
i = hepi.Input(hepi.Order.NLO,7000,1000002,1000022,"sps1a1000.in","cteq6l1","cteq6l1",1., 1.,"test_rnlo_QQ")
li = hepi.mass_scan([i],1000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,1000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,1000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,1000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,1000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>--nlo                                    Stage: DONE                                     Status DONE</pre>
#   </div>
# </div>

# %%
rs.set_path("~/git/resummino_ug_to_UX_vNLO/")
i = hepi.Input(hepi.Order.NLO,7000,2000002,1000022,"sps1a1000.in","cteq6l1","cteq6l1",1., 1.,"test_rnlo_QQ")
li = hepi.mass_scan([i],2000002, range(300,1000,50),diff_L_R=20)
dll = rs.run(li,True)
hepi.mass_plot(dll,2000002,"lo",yscale=1000,yaxis="$\sigma$ [fb]")
hepi.mass_plot(dll,2000002,"rnlo",yscale=1000,yaxis="$\sigma$ [fb]")
smpl.plot.show()
hepi.mass_vplot(dll,2000002,((dll["rnlo"]+dll["lo"])/dll["lo"]),logy=False,label="$K_\\mathrm{rnlo}$")
hepi.mass_plot(dll,2000002,"K_lo",logy=False,label="$K_\\mathrm{lo}$")
# Out:
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>./output/order_Order.NLO_energy_7000_particle1_2000002_particle2_1000022_slha_sps1a1000.in_2000002_300_pdf_lo_cteq6l1_pdf_nlo_cteq6l1_mu_f_1.0_mu_r_1.0_id_test_rnlo_QQ_mass_2000002_300.out</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 300 ... 300.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 350 ... 350.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 400 ... 400.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 450 ... 450.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 500 ... 500.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 550 ... 550.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 600 ... 600.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 650 ... 650.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 700 ... 700.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 750 ... 750.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 800 ... 800.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 850 ... 850.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 900 ... 900.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre> ... 950 ... 950.out                  Stage: DONE                    Status DONE:                   </pre>
#   </div>
# </div>
