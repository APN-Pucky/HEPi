# %%
import hepi
print(hepi.__version__)
import smpl
import numpy as np
import hepi.prospino2 as ps
import hepi.resummino as rs
import hepi.madgraph as mg
import hepi.util as util
import matplotlib.pyplot as plt
rs.set_path("~/git/resummino")
ps.set_path("/home/apn/git/Prospino2")
print (ps.get_path())
mg.set_path("/opt/MG5_aMC_v2_7_3")
model_path="/opt/MG5_aMC_v2_7_3/models/EWKino_NLO_UFO"
# Out:
# 0.1.4.18+dirty
# /home/apn/git/Prospino2/

# %%
params = [
    "mastercode_with_gm2.in",
    #"mastercode_no_gm2_mod.in",
]
pss = [ 
    
      (1000022,1000022),
    
    
    
     ]

# %% [markdown]
# # Mass

# %%
for pa,pb in pss:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"cteq6l1","cteq66",1., 1.,model_path=model_path,id="5")
        #i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path,id="5")
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(1000,4000,8))
        rs_dl = rs.run(li,noskip=False,run=False,parse=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1678/1312945173.py in <module>
# ----> 1 for pa,pb in pss:
#       2     for param in params:
#       3         i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"cteq6l1","cteq66",1., 1.,model_path=model_path,id="5")
#       4         #i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path,id="5")
#       5         li = [i]
#
# NameError: name 'pss' is not defined

# %%
pss = [ 
    
      (1000022,1000021),
    
    
    
     ]
for pa,pb in pss:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"cteq6l1","cteq66",1., 1.,model_path=model_path,id="5")
        #i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path,id="5")
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(100,1000,16))
        mg_dl = mg.run(li,noskip=True)
        ps_dl = ps.run(li,skip=True)
        rs_dl = rs.run(li,noskip=False)
        o="NLO"
        rs_dl['rel_diff_mg'] = (rs_dl[o]-mg_dl[o])/rs_dl[o]
        rs_dl['rel_diff_ps'] = (rs_dl[o]-ps_dl[o])/rs_dl[o]
        print(mg_dl)
        hepi.mass_plot(ps_dl,"LO",pa,logy=True)
        hepi.mass_plot(mg_dl,"LO",pa,logy=True)
        hepi.mass_plot(rs_dl,"LO",pa,logy=True)
        hepi.mass_plot(ps_dl,"NLO",pa,logy=True)
        hepi.mass_plot(mg_dl,"NLO",pa,logy=True)
        hepi.mass_plot(rs_dl,"NLO",pa,logy=True)
        smpl.plot.show()

        hepi.mass_plot(rs_dl,"rel_diff_ps",pa,logy=False,label="rel_diff_PS",yaxis="rel diff")
        hepi.mass_plot(rs_dl,"rel_diff_mg",pa,logy=False,label="rel_diff_MG",yaxis="rel diff")
        smpl.plot.show()
        hepi.mass_plot(ps_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        hepi.mass_plot(mg_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        hepi.mass_plot(rs_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        smpl.plot.show()
# Out:
# ./output/363e19cce2ed9c4dd9efa75cd76cbb2d667b31c4ea85f2886b00a40d77f9cd2e.out
# No module named 'madgraph'
#  No hepmc reader since No module named 'madgraph' [lhe_parser.py at line 50]
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3.py3           20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/363e19cce2ed9c4dd9efa75cd76cbb2d667b31c4ea85f2886b00a40d77f9cd2e.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_3/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/363e19cce2ed9c4dd9efa75cd76cbb2d667b31c4ea85f2886b00a40d77f9cd2e.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "evince". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# write ./param_card.dat
# INFO: For gauge cancellation, the width of 'go' has been set to zero.
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 8 cores
# INFO:  Compiling P0_uux_n1go...
# INFO:  Compiling P0_ccx_n1go...
# INFO:  Compiling P0_ddx_n1go...
# INFO:  Compiling P0_ssx_n1go...
# INFO:  Compiling P0_uxu_n1go...
# INFO:  Compiling P0_cxc_n1go...
# INFO:  Compiling P0_dxd_n1go...
# INFO:  Compiling P0_sxs_n1go...
# INFO:     P0_ssx_n1go done.
# INFO:  Compiling P0_bbx_n1go...
# INFO:     P0_dxd_n1go done.
# INFO:  Compiling P0_bxb_n1go...
# INFO:     P0_uux_n1go done.
# INFO:     P0_sxs_n1go done.
# INFO:     P0_ccx_n1go done.
# INFO:     P0_uxu_n1go done.
# INFO:     P0_cxc_n1go done.
# INFO:     P0_ddx_n1go done.
# INFO:     P0_bxb_n1go done.
# INFO:     P0_bbx_n1go done.
# INFO: Checking test output:
# INFO: P0_uux_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1go
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 8 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 2,  Running: 8,  Completed: 0 [ current time: 12h25 ]
# INFO:  Idle: 1,  Running: 8,  Completed: 1 [  13m 8s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  13m 23s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  13m 35s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  13m 56s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  14m 1s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  14m 3s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  14m 25s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  15m 16s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  20m 20s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  20m 52s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      -2.827e-01 +- 5.2e-03 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 2,  Running: 8,  Completed: 0 [ current time: 12h46 ]
# INFO:  Idle: 1,  Running: 8,  Completed: 1 [  1m 46s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  1m 53s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  2m 23s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  3m 22s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  3m 24s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  3m 25s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  3m 27s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  3m 53s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  4m 10s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  4m 26s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000021 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: -2.981e-01 +- 4.7e-03 pb
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/363e19cce2ed9c4dd9efa75cd76cbb2d667b31c4ea85f2886b00a40d77f9cd2e.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/2b60104f7ae52afdca5935aa22aef116db123ad2e97eae713656845c8de937cb.dir/SubProcesses/P0_ddx_n1go/ajob1 1 all 0 0 launch ends with non zero status: -2. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/2b60104f7ae52afdca5935aa22aef116db123ad2e97eae713656845c8de937cb.dir/run_03_tag_1_debug.log'.
# Please attach this file to your report.
# Command "calculate_xsect -f" interrupted with error:
# Exception : program /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/c0c22f21748c5b1c098e126623fc2e255b87f8c08952260fbae73cafa9ead7de.dir/SubProcesses/P0_uux_n1go/ajob1 1 all 1 1 launch ends with non zero status: -2. Stop all computation
# Please report this bug on https://bugs.launchpad.net/mg5amcnlo
# More information is found in '/home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/c0c22f21748c5b1c098e126623fc2e255b87f8c08952260fbae73cafa9ead7de.dir/run_03_tag_1_debug.log'.
# Please attach this file to your report.
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/6869b605b3b55c5bd58a83ffc00fb565179f8ae49718b5f5315e76eb34727729.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/0d5f92b4ae72f9b3464e36608f8fc972955f6d0e87346f0da34344a2c70d5390.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/363e19cce2ed9c4dd9efa75cd76cbb2d667b31c4ea85f2886b00a40d77f9cd2e.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/e8e3ce996168095dca5cf33cebb20158408c40d0f337ac6f830316e0cac79bd1.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/3f1bae6e456afa5ae9921bcca1105f3149a7d64d37b68f9d6f77e53e6a262249.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/90efbf7a564aadb938956a18edb7b66f8d763f00c374b610d4dccb63ee9b7b7a.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/4640c0c382371d271192d9d7fb630ad488865407f528d76558c4d790306dc703.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/2bf432a18fafd6f68d95fd75c10b49d53e2f58faef1a363d9c4207cd8c9a45a7.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/537d9883c6d2c35a492b065edb4963d1b7e80621a1e574b361ce6154b9c3ef95.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/cc0c885fff652eecd942d7e78c9f8bc6ba3bd62d24b3aab7ba523ca3a72cf8f8.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/de8ab78fbeb4176fd73faee44c9425d1fd008042edd482ff64dfd261a5992c0b.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/c6200f98f5f320ba491e8b0fdcbe3e8aa64c51a6bcc197f4efa48627d55d9661.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/bc8e96e63119c91ccbc833ab48fd2a11d6683e9eaae9357d8a4c0a198ad1a27e.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/50552beebb8a0cbcb5ed823832bdb6b40d394caac0ae4dcb895042a508a81d0e.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22757/1999899189.py in <module>
#      12         li = [i]
#      13         li = hepi.mass_scan([i],pa, np.linspace(100,1000,16))
# ---> 14         mg_dl = mg.run(li,noskip=True)
#      15         ps_dl = ps.run(li,skip=True)
#      16         rs_dl = rs.run(li,noskip=False)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in run(params, noskip, madstr, para)
#      57 def run(params: List[Input], noskip=False,madstr=True,para=True):
#      58     rps = _queue(params, noskip,madstr)
# ---> 59     _run(rps,para)
#      60     outs = LD2DL(rps)["dic"]
#      61     results = _parse(outs)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in _run(rps, para)
#     161
#     162     # Collect statuses
# --> 163     output = [p.wait() for p in processes]
#     164     return output
#     165
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in <listcomp>(.0)
#     161
#     162     # Collect statuses
# --> 163     output = [p.wait() for p in processes]
#     164     return output
#     165
#
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1804                         if self.returncode is not None:
#    1805                             break  # Another thread waited.
# -> 1806                         (pid, sts) = self._try_wait(0)
#    1807                         # Check the pid and loop as waitpid has been known to
#    1808                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1762             """All callers to this function MUST hold self._waitpid_lock."""
#    1763             try:
# -> 1764                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1765             except ChildProcessError:
#    1766                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
params = [
    "mastercode_with_gm2.in",
    "mastercode_with_gm2_red.in",
]
pss = [ 
    (1000022,1000022),
      (1000022,1000021),
     ]
for pa,pb in pss:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"cteq6l1","cteq66",1., 1.,model_path=model_path,id="5")
        #i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path,id="5")
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(100,1000,6))
        mg_dl = mg.run(li,noskip=True)
        #ps_dl = ps.run(li,skip=True)
        rs_dl = rs.run(li,noskip=False)
        o="NLO"
        rs_dl['rel_diff_mg'] = (rs_dl[o]-mg_dl[o])/rs_dl[o]
        #rs_dl['rel_diff_ps'] = (rs_dl[o]-ps_dl[o])/rs_dl[o]
        #hepi.mass_plot(ps_dl,"LO",pa,logy=True)
        hepi.mass_plot(mg_dl,"LO",pa,logy=True)
        hepi.mass_plot(rs_dl,"LO",pa,logy=True)
        #hepi.mass_plot(ps_dl,"NLO",pa,logy=True)
        hepi.mass_plot(mg_dl,"NLO",pa,logy=True)
        hepi.mass_plot(rs_dl,"NLO",pa,logy=True)
        smpl.plot.show()

        #hepi.mass_plot(rs_dl,"rel_diff_ps",pa,logy=False,label="rel_diff_PS",yaxis="rel diff")
        hepi.mass_plot(rs_dl,"rel_diff_mg",pa,logy=False,label="rel_diff_MG",yaxis="rel diff")
        smpl.plot.show()
        #hepi.mass_plot(ps_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        hepi.mass_plot(mg_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        hepi.mass_plot(rs_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        smpl.plot.show()
# Out:
# ./output/8a637603bdec5ff3086964604ac1466851ff97fbb410d2d4fe8eb9d763ea98f6.out
# No module named 'madgraph'
#  No hepmc reader since No module named 'madgraph' [lhe_parser.py at line 50]
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3.py3           20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/8a637603bdec5ff3086964604ac1466851ff97fbb410d2d4fe8eb9d763ea98f6.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_3/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/8a637603bdec5ff3086964604ac1466851ff97fbb410d2d4fe8eb9d763ea98f6.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "evince". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# write ./param_card.dat
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 8 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:     P0_uux_n1n1 done.
# INFO:  Compiling P0_bbx_n1n1...
# INFO:     P0_dxd_n1n1 done.
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_uxu_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 18 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 18 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 8 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 2,  Running: 8,  Completed: 0 [ current time: 08h08 ]
# Terminated
# Terminated
# INFO: rm jobs on queue
# INFO: Stop by the user
# stopping all operation
#             in order to quit MadGraph5_aMC@NLO please enter exit
# quit
# INFO:
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/8a637603bdec5ff3086964604ac1466851ff97fbb410d2d4fe8eb9d763ea98f6.bdir/run_01_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15324/1518050009.py in <module>
#      13         li = [i]
#      14         li = hepi.mass_scan([i],pa, np.linspace(100,1000,6))
# ---> 15         mg_dl = mg.run(li,noskip=True)
#      16         #ps_dl = ps.run(li,skip=True)
#      17         rs_dl = rs.run(li,noskip=False)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in run(params, noskip, madstr, para)
#      57 def run(params: List[Input], noskip=False,madstr=True,para=True):
#      58     rps = _queue(params, noskip,madstr)
# ---> 59     _run(rps,para)
#      60     outs = LD2DL(rps)["dic"]
#      61     results = _parse(outs)
#
# ~/.local/lib/python3.8/site-packages/hepi/madgraph/run.py in _run(rps, para)
#     147             ' --file {in} >> {out} && cp {slha} {bdir}/Cards/param_card.dat && cp {run} {bdir}/Cards/run_card.dat && sed -i \'s/.*= req_acc_FO/ 1 = req_acc_FO/g\' {bdir}/Cards/run_card.dat && echo "automatic_html_opening = False" >> {bdir}/Cards/amcatnlo_configuration.txt && nice -n 5 {bdir}/bin/calculate_xsect -f'
#     148         pp = subprocess.Popen(com.format(**rps[0].dic), shell=True)
# --> 149         pp.wait()
#     150     # Run commands in parallel
#     151     processes = []
#
# /usr/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1804                         if self.returncode is not None:
#    1805                             break  # Another thread waited.
# -> 1806                         (pid, sts) = self._try_wait(0)
#    1807                         # Check the pid and loop as waitpid has been known to
#    1808                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1762             """All callers to this function MUST hold self._waitpid_lock."""
#    1763             try:
# -> 1764                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1765             except ChildProcessError:
#    1766                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
params = [
]
pss = [ 
      (1000022,1000022),
     ]
for pa,pb in pss:
    for param in params:
        i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"cteq6l1","cteq66",1., 1.,model_path=model_path,id="5")
        #i = hepi.Input(hepi.Order.NLO,13000,pa,pb,param,"CT14lo","CT14lo",1., 1.,model_path=model_path,id="5")
        li = [i]
        li = hepi.mass_scan([i],pa, np.linspace(100,1000,6))
        mg_dl = mg.run(li,noskip=True)
        #ps_dl = ps.run(li,skip=True)
        rs_dl = rs.run(li,noskip=False)
        o="NLO"
        rs_dl['rel_diff_mg'] = (rs_dl[o]-mg_dl[o])/rs_dl[o]
        #rs_dl['rel_diff_ps'] = (rs_dl[o]-ps_dl[o])/rs_dl[o]
        #hepi.mass_plot(ps_dl,"LO",pa,logy=True)
        hepi.mass_plot(mg_dl,"LO",pa,logy=True)
        hepi.mass_plot(rs_dl,"LO",pa,logy=True)
        #hepi.mass_plot(ps_dl,"NLO",pa,logy=True)
        hepi.mass_plot(mg_dl,"NLO",pa,logy=True)
        hepi.mass_plot(rs_dl,"NLO",pa,logy=True)
        smpl.plot.show()

        #hepi.mass_plot(rs_dl,"rel_diff_ps",pa,logy=False,label="rel_diff_PS",yaxis="rel diff")
        hepi.mass_plot(rs_dl,"rel_diff_mg",pa,logy=False,label="rel_diff_MG",yaxis="rel diff")
        smpl.plot.show()
        #hepi.mass_plot(ps_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        hepi.mass_plot(mg_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        hepi.mass_plot(rs_dl,"K_NLO",pa,yaxis="K_NLO",logy=True)
        smpl.plot.show()
# Out:
# ./output/2d8570908625aaa9c369336ed618bde4aaaa63e574a03ecd90fd3c7ce5f670ed.out
# No module named 'madgraph'
#  No hepmc reader since No module named 'madgraph' [lhe_parser.py at line 50]
# INFO: ************************************************************
# *                                                          *
# *           W E L C O M E  to  M A D G R A P H 5           *
# *                       a M C @ N L O                      *
# *                                                          *
# *                 *                       *                *
# *                   *        * *        *                  *
# *                     * * * * 5 * * * *                    *
# *                   *        * *        *                  *
# *                 *                       *                *
# *                                                          *
# *         VERSION 5.2.7.3.py3           20xx-xx-xx         *
# *                                                          *
# *    The MadGraph5_aMC@NLO Development Team - Find us at   *
# *                 http://amcatnlo.cern.ch                  *
# *                                                          *
# *               Type 'help' for in-line help.              *
# *                                                          *
# ************************************************************
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/2d8570908625aaa9c369336ed618bde4aaaa63e574a03ecd90fd3c7ce5f670ed.bdir/Cards/amcatnlo_configuration.txt
# INFO: load configuration from /opt/MG5_aMC_v2_7_3/input/mg5_configuration.txt
# INFO: load configuration from /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/2d8570908625aaa9c369336ed618bde4aaaa63e574a03ecd90fd3c7ce5f670ed.bdir/Cards/amcatnlo_configuration.txt
# Using default eps viewer "evince". Set another one in ./input/mg5_configuration.txt
# Using default web browser "firefox". Set another one in ./input/mg5_configuration.txt
# calculate_xsect -f
# INFO: will run in mode: NLO
# INFO: Starting run
# INFO: Compiling the code
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# write ./param_card.dat
# INFO: MadSTR: Forcing width MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSUR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSCR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBL to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSDR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSSR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MDL_WSBR to zero inside param_card.inc
# INFO: MadSTR: Forcing width MP__MDL_WSBR to zero inside param_card.inc
# WARNING: The replacements above ensure poles cancelation, and affect all widths
#    EXCEPT those which enter the resonance-treatment counterterms, which
#    are taken from the param_card.
#    Do NOT set these widths to zero in the param_card.
# INFO: Using LHAPDF v6.3.0 interface for PDFs
# INFO: Compiling source...
# INFO:           ...done, continuing with P* directories
# WARNING: Could not compile StdHEP because its source directory could not be found in the SOURCE folder.
#  Check the MG5_aMC option 'output_dependencies'.
#  This will prevent the use of HERWIG6/Pythia6 shower.
# INFO: Compiling directories...
# INFO: Compiling on 8 cores
# INFO:  Compiling P0_uux_n1n1...
# INFO:  Compiling P0_ccx_n1n1...
# INFO:  Compiling P0_ddx_n1n1...
# INFO:  Compiling P0_ssx_n1n1...
# INFO:  Compiling P0_uxu_n1n1...
# INFO:  Compiling P0_cxc_n1n1...
# INFO:  Compiling P0_dxd_n1n1...
# INFO:  Compiling P0_sxs_n1n1...
# INFO:     P0_uux_n1n1 done.
# INFO:  Compiling P0_bbx_n1n1...
# INFO:     P0_uxu_n1n1 done.
# INFO:  Compiling P0_bxb_n1n1...
# INFO:     P0_ssx_n1n1 done.
# INFO:     P0_ccx_n1n1 done.
# INFO:     P0_ddx_n1n1 done.
# INFO:     P0_cxc_n1n1 done.
# INFO:     P0_dxd_n1n1 done.
# INFO:     P0_sxs_n1n1 done.
# INFO:     P0_bbx_n1n1 done.
# INFO:     P0_bxb_n1n1 done.
# INFO: Checking test output:
# INFO: P0_uux_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ccx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ddx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_ssx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_uxu_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_cxc_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_dxd_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_sxs_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 20 points over 20 (tolerance=1.0e-05)
# INFO: P0_bbx_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 18 points over 20 (tolerance=1.0e-05)
# INFO: P0_bxb_n1n1
# INFO:  Result for test_ME:
# INFO:    Passed.
# INFO:  Result for check_poles:
# INFO:    Poles successfully cancel for 18 points over 20 (tolerance=1.0e-05)
# INFO: Starting run
# INFO: Using 8 cores
# INFO: Cleaning previous results
# INFO: Doing fixed order NLO
# INFO: Setting up grids
# INFO:  Idle: 2,  Running: 8,  Completed: 0 [ current time: 16h25 ]
# INFO:  Idle: 1,  Running: 8,  Completed: 1 [  5m 6s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  5m 16s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  5m 33s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  5m 34s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  5m 39s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  6m 7s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  7m 9s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  8m 32s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  8m 38s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  8m 57s  ]
# INFO:
#       Results after grid setup:
#       Total cross section:      7.316e-06 +- 2.4e-07 pb
#
# INFO: Refining results, step 1
# INFO:  Idle: 2,  Running: 8,  Completed: 0 [ current time: 16h34 ]
# INFO:  Idle: 1,  Running: 8,  Completed: 1 [  1m 54s  ]
# INFO:  Idle: 0,  Running: 8,  Completed: 2 [  2m 9s  ]
# INFO:  Idle: 0,  Running: 7,  Completed: 3 [  2m 10s  ]
# INFO:  Idle: 0,  Running: 6,  Completed: 4 [  2m 13s  ]
# INFO:  Idle: 0,  Running: 5,  Completed: 5 [  2m 52s  ]
# INFO:  Idle: 0,  Running: 4,  Completed: 6 [  3m 57s  ]
# INFO:  Idle: 0,  Running: 3,  Completed: 7 [  4m 1s  ]
# INFO:  Idle: 0,  Running: 2,  Completed: 8 [  4m 5s  ]
# INFO:  Idle: 0,  Running: 1,  Completed: 9 [  4m 28s  ]
# INFO:  Idle: 0,  Running: 0,  Completed: 10 [  4m 58s  ]
# INFO:
#    --------------------------------------------------------------
#       Final results and run summary:
#       Process p p > 1000022 1000022 [QCD]
#       Run at p-p collider (6500.0 + 6500.0 GeV)
#       Total cross section: 7.403e-06 +- 1.2e-07 pb
#    --------------------------------------------------------------
#
# INFO: The results of this run and the HwU and GnuPlot files with the plots have been saved in /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/2d8570908625aaa9c369336ed618bde4aaaa63e574a03ecd90fd3c7ce5f670ed.bdir/Events/run_01
# INFO: Run complete
# INFO:
# quit
# INFO:
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# stty: 'standard input': Inappropriate ioctl for device
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/a06aa93d254ab891852d7ac89be1678b9699a777a604fd95c43bd2967bdd2c8c.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str : Poles do not cancel, run cannot continue
# Error detected in "calculate_xsect -f"
# write debug file /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/hepi/tests/output/2d8570908625aaa9c369336ed618bde4aaaa63e574a03ecd90fd3c7ce5f670ed.dir/run_03_tag_1_debug.log
# If you need help with this issue please contact us on https://answers.launchpad.net/mg5amcnlo
# str : Poles do not cancel, run cannot continue
# Running: 6 jobs
